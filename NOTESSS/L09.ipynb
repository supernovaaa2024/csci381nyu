# %% [markdown]
# # **Pandas Essentials**
# This notebook covers everything from basic data structures to advanced grouping and time-series analysis.

# %% [markdown]
# ## 1. Setup and Series
# A **Series** is a one-dimensional labeled array.

# %%
import pandas as pd
import numpy as np

# Dealing with Series
s = pd.Series([10, 20, 30], index=['a', 444, 'welcome'])  # Create a Pandas Series with custom index labels: 'a', 444, and 'welcome'
s
# Out:
# a          10
# 444        20
# welcome    30
# dtype: int64

# %%
s['a']        # Access the value in Series `s` using label 'a'
s[444]        # Access the value in Series `s` using label or integer index 444 (depends on the index type)
s['welcome']  # Access the value in Series `s` using label 'welcome'
type(s)       # Return the type of object `s` (usually pandas Series)
s.dtype       # Return the data type of the values stored in the Series
# Out:
# dtype('int64')

# %% [markdown]
# ## 2. Creating DataFrames
# We can create DataFrames using dictionaries or lists of lists.

# %%
# Dictionary Method
d = {'name': ['james', 'maya', 'tara'],   # Dictionary key 'name' with a list of employee names
     'age': [20, 27, 2000],               # Dictionary key 'age' with corresponding ages (note: 2000 looks like an outlier)
     'salary': [2000, 3000, 4000]}        # Dictionary key 'salary' with corresponding salaries
df1 = pd.DataFrame(d)                     # Create a DataFrame from dictionary `d`
df1
# Out:
#     name   age  salary
# 0  james    20    2000
# 1   maya    27    3000
# 2   tara  2000    4000

# %%
df1.name[1]
# Out:
# 'maya'

# %%
# List of Lists Method
LL = [['james', 20, 2000], ['maya', 27, 3000], ['tara', 25, 4000]]  # Create a list of lists (each inner list represents a row)
df2 = pd.DataFrame(LL, columns=['name', 'age', 'salary'])           # Create a DataFrame from LL and assign column names
df2
# Out:
#     name  age  salary
# 0  james   20    2000
# 1   maya   27    3000
# 2   tara   25    4000

# %%
df = pd.read_csv('students.csv')  # Read a CSV file into a DataFrame using comma as the separator

# %% [markdown]
# ## 3. Inspection and Preparation
# Understanding the metadata and structure of your data.

# %%
df=pd.read_csv('students.csv')
df
# Out:
#    student  score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
df.columns
# Out:
# Index(['student', 'score'], dtype='str')

# %%
# df.columns      # Return the column labels of the DataFrame
# df.index        # Return the index (row labels) of the DataFrame
# df.values       # Return the underlying NumPy array of the DataFrame
# df.shape
# df.head(2)       # Display the first 5 rows of the DataFrame
# df.tail()       # Display the last 5 rows of the DataFrame
# df.describe()   # Generate summary statistics (count, mean, std, min, quartiles, max) for numeric columns
df.info()       # Display DataFrame structure, column data types, and non-null counts
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   student  3 non-null      str
#  1   score    3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 195.0 bytes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([['Alice', 85],
#        ['Bob', 90],
#        ['Charlie', 78]], dtype=object)

# %%
df.shape
# Out:
# (3, 2)

# %%
df.head()
# Out:
#    student  score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
# Index Manipulation
df.set_index("student")  # Set one or more existing columns as the DataFrame index (column name(s) must be specified_
# Out:
#          score
# student
# Alice       85
# Bob         90
# Charlie     78

# %%
import pandas as pd

# Create a DataFrame with index labels including 4
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'age': [23, 34, 45, 28, 30]
}, index=[0, 1, 2, 3, 4])

print(df)

# Now you can drop the row with index label 4
df.drop(4, inplace=True)
print("\nAfter dropping index 4:\n", df) # Drop the row with index label 4 and modify the DataFrame in place
# Out:
#       name  age
# 0    Alice   23
# 1      Bob   34
# 2  Charlie   45
# 3    David   28
# 4      Eve   30
#
# After dropping index 4:
#        name  age
# 0    Alice   23
# 1      Bob   34
# 2  Charlie   45
# 3    David   28

# %%
df = df.drop(4)           # Drop the row with index label 4 and assign the result to df
df.drop(4, axis=0)        # Drop the row with index label 4 (axis=0 refers to rows)
df.drop('age', axis=1)    # Drop the column named 'age'
del df['age']             # Delete the column 'age' from the DataFrame
df['state'] = 'NY'        # Add a new column 'state' with all values set to 'NY'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 df = df.drop(4)           # Drop the row with index label 4 and assign the result to df
#       2 df.drop(4, axis=0)        # Drop the row with index label 4 (axis=0 refers to rows)
#       3 df.drop('age', axis=1)    # Drop the column named 'age'
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: '[4] not found in axis'

# %% [markdown]
# ## 4. Handling Missing Values
# Common strategies for cleaning incomplete data.

# %%
df=pd.read_csv("missingvaluesfile.csv", index_col=0)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df=pd.read_csv("missingvaluesfile.csv", index_col=0)
#       2 df
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'missingvaluesfile.csv'

# %%
# df = df.one.replace(-1, np.nan)    # Replace all 0 values in the DataFrame with NaN (missing values)
# df.isna()                          # Return a boolean DataFrame indicating where values are NaN
# df.isnull()                        # Return a boolean DataFrame indicating where values are null (NaN)
# df.isna().sum()                    # Count the number of NaN values in each column
# df.isna().sum(axis=1)              # Count the number of NaN values in each row
# df.isna().sum().sum()              # Count the total number of NaN values across all rows
# np.sum(df.isna(), axis=0)          # Count the number of NaN values in each column
# np.sum(df.isna(), axis=1)          # Count the number of NaN values in each row
# np.sum(np.sum(df.isna(), axis=0))  # Count the total number of NaN values in the entire DataFrame

# %%
# df.dropna(axis=0, how='any')  # Remove rows that contain at least one NaN value
# df.dropna(axis=1, how='all')  # Drop columns where all values are NaN (modify in place)
# df.dropna(axis=1, how='any')  # Drop columns that contain at least one NaN value

# %%
# df_na.fillna(0)                             # Replace all NaN values with 0
# df['one'] = df['one'].fillna(df['one'].mean())  # Replace NaN values in column 'one' with its mean
# df_na.interpolate()                         # Fill NaN values using interpolation
# df.interpolate(method='linear')             # Fill NaN values using linear interpolation
# df.interpolate(method='index')              # Fill NaN values using index-based interpolation

# %% [markdown]
# ## 5. Selecting Data
# Methods for accessing specific rows and columns.

# %%
df.set_index('education', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gj/84cwp0nn3tv2_r__6jbrp5hc0000gn/T/ipykernel_97854/4031510878.py in ?()
# ----> 1 df.set_index('education', inplace=True)
#
# ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6973                     if not found:
#    6974                         missing.append(col)
#    6975
#    6976         if missing:
# -> 6977             raise KeyError(f"None of {missing} are in the columns")
#    6978
#    6979         if inplace:
#    6980             frame = self
#
# KeyError: "None of ['education'] are in the columns"

# %%
# df['col_name']['row_name']      # Access a value by first selecting a column, then a row label (not recommended)
# df.loc['row_name', 'col_name']  # Access a value using explicit row and column labels
# df.iloc[row_id, col_id]         # Access a value using integer-based row and column positions

# %%
# df['age']['MBA']
# df[['age']]

# %%
# df.loc['MBA', 'age']
# df.loc['MBA', ['age','name']]
# df.loc[['MBA','BA'], ['age','name']]
# df.loc[:,['department','name']]
# df.loc['MBA', :]
# df.loc[df.age>22,:]
# df.loc[df.age==27,['name','department']]
# df.loc[(df.age>25)&(df.department=='math'),:]
# df.loc[(df.age>25) & (df.department=='math'),['name']]
# df.loc[(df.age>30)|(df.age<25),['name','age']]

# %%
# df.iloc[0, :]            # Select the first row (all columns) using integer position
# df.iloc[[0, -1], :]      # Select the first and last rows (all columns)
# df.iloc[[0, -1], 0]      # Select the first column values from the first and last rows
# df.iloc[[0, -1],[0, -1]] # Select the first and last columns from the first and last rows
# df.iloc[:3, :]           # Select the first three rows (all columns)
# df.iloc[-4:, :]          # Select the last four rows (all columns)
# df.iloc[::2, :]          # Select every second row (all columns)
# df.iloc[::-1, :]         # Reverse the row order (all columns)
# df.iloc[:, -2:]          # Select the last two columns (all rows)

# %% [markdown]
# ## 6. Analysis: Grouping and Pivoting
# Summarizing data for insights.

# %%
df.reset_index(inplace=True)

# %%
# df.groupby('col_name')          # Group the DataFrame by the values in column 'col_name'
for t in df.groupby('education'): # Iterate over groups created from the 'education' column
    print(t[0])                   # Print the group name (unique value of 'education')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 2
#       1 # df.groupby('col_name')          # Group the DataFrame by the values in column 'col_name'
# ----> 2 for t in df.groupby('education'): # Iterate over groups created from the 'education' column
#       3     print(t[0])                   # Print the group name (unique value of 'education')
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'education'

# %%
# df.groupby('department')        # Group the DataFrame by the values in the 'department' column
df.groupby('education').size()    # Count the number of rows in each 'education' group
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 2
#       1 # df.groupby('department')        # Group the DataFrame by the values in the 'department' column
# ----> 2 df.groupby('education').size()    # Count the number of rows in each 'education' group
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'education'

# %%
# df[['education','age','id']].groupby('education').mean()              # Compute the mean of 'age' and 'id' for each education group
# df[['education','age','id']].groupby('education').min()               # Compute the minimum of 'age' and 'id' for each education group
# df[['education','age','id']].groupby('education').max()               # Compute the maximum of 'age' and 'id' for each education group
# df[['education','age']].groupby('education').agg(['min','mean','max']) # Compute min, mean, and max of 'age' for each education group

# %%
# for t in df[['education','department','age']].groupby(['department', 'education']):
#     print(t[0])

# %%
df[['education','department','age']].groupby(['department', 'education']).mean()     # Compute the mean of 'age' for each combination of department and education (department is primary group)
df[['education','department','age']].groupby(['education', 'department']).mean()     # Compute the mean of 'age' for each combination of education and department (education is primary group)
df[['education','department','age']].groupby(['education', 'department']).agg(['min','max'])  # Compute min and max of 'age' for each combination of education and department
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df[['education','department','age']].groupby(['department', 'education']).mean()     # Compute the mean of 'age' for each combination of department and education (department is primary group)
#       2 df[['education','department','age']].groupby(['education', 'department']).mean()     # Compute the mean of 'age' for each combination of education and department (education is primary group)
#       3 df[['education','department','age']].groupby(['education', 'department']).agg(['min','max'])  # Compute min and max of 'age' for each combination of education and department
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/indexes/base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['education', 'department', 'age'], dtype='str')] are in the [columns]"

# %%
# .filter(lambda x: condition) keeps only the groups where the lambda returns True.
# Keep only groups where the average age is greater than 30
# df.groupby('department').filter(lambda x: x['age'].mean() > 30)

# Keep only groups with more than 2 members
# df.groupby('department').filter(lambda x: len(x) > 2)

# %% [markdown]
# ### 7. Pivot Table Explanation
#
# A pivot table in Pandas is used to **summarize and aggregate data** in a table format.
#
# - `index` → rows
# - `columns` → columns
# - `values` → values to aggregate
# - `aggfunc` → aggregation function (default is `mean`)
#
# It is especially useful for **grouping data** and **computing statistics** across multiple categories.

# %%
# Basic pivot table: average age per education and department
df.pivot_table(index='education', columns='department', values='age')  

# Pivot table with sum aggregation
df.pivot_table(index='education', columns='department', values='age', aggfunc='sum')  

# Pivot table with multiple aggregation functions
df.pivot_table(index='education', columns='department', values='age', aggfunc=['mean','min','max'])  

# Pivot table including all columns
df.pivot_table(index='education', values=['age','id'], aggfunc='mean')  

# Pivot table with fill value for missing data
df.pivot_table(index='education', columns='department', values='age', fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 2
#       1 # Basic pivot table: average age per education and department
# ----> 2 df.pivot_table(index='education', columns='department', values='age')
#       4 # Pivot table with sum aggregation
#       5 df.pivot_table(index='education', columns='department', values='age', aggfunc='sum')
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:11143, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11125 @Substitution("")
#   11126 @Appender(_shared_docs["pivot_table"])
#   11127 def pivot_table(
#    (...)  11139     **kwargs,
#   11140 ) -> DataFrame:
#   11141     from pandas.core.reshape.pivot import pivot_table
# > 11143     return pivot_table(
#   11144         self,
#   11145         values=values,
#   11146         index=index,
#   11147         columns=columns,
#   11148         aggfunc=aggfunc,
#   11149         fill_value=fill_value,
#   11150         margins=margins,
#   11151         dropna=dropna,
#   11152         margins_name=margins_name,
#   11153         observed=observed,
#   11154         sort=sort,
#   11155         **kwargs,
#   11156     )
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
#     281 return table.__finalize__(data, method="pivot_table")
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:315, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, kwargs)
#     313 for i in values:
#     314     if i not in data:
# --> 315         raise KeyError(i)
#     317 to_filter = []
#     318 for x in keys + values:
#
# KeyError: 'age'
