# %% [markdown]
# # **Combining DataFrames**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## `pd.concat()`

# %% [markdown]
# `pd.concat()` is a **Pandas function used to combine multiple DataFrames or Series** along a specified axis.
#
# - **`axis=0`** → Stacks data **vertically** (adds rows).
# - **`axis=1`** → Combines data **horizontally** (adds columns).
# - **`join='outer'`** → Keeps all indexes (union of indexes).
# - **`join='inner'`** → Keeps only common indexes (intersection of indexes).
#
# It is commonly used to append datasets or combine related data structures into a single DataFrame.

# %%
df1=pd.DataFrame(np.arange(9).reshape(3,3), columns=['a','b','c'], index=['one', 'two', 'three'])
df1
# Out:
#        a  b  c
# one    0  1  2
# two    3  4  5
# three  6  7  8

# %%
df2=pd.DataFrame(np.arange(6).reshape(-1,2), columns=['d','e'], index=['three', 'two', 'One'])
df2
# Out:
#        d  e
# three  0  1
# two    2  3
# One    4  5

# %%
nums = [1, 2, 3, 4, 5]
print(nums[-3::-1])
print(nums[-3:-1])
# Out:
# [3, 2, 1]
# [3, 4]

# %% [markdown]
# ### More Tricky List Slicing Examples
# - `nums = [1, 2, 3, 4, 5]`
# - `nums[::2]` → Every other element: `[1, 3, 5]`
# - `nums[::-1]` → Reversed list: `[5, 4, 3, 2, 1]`
# - `nums[1:-1]` → All except first and last: `[2, 3, 4]`
# - `nums[-4:-1]` → From 2nd to 4th from end: `[2, 3, 4]`
# - `nums[1:100]` → Slices safely even if stop > length: `[2, 3, 4, 5]`
# - `nums[-100:3]` → Slices safely even if start < 0: `[1, 2, 3]`
# - `nums[3:1:-1]` → Slices backwards: `[4, 3]`
# - `nums[1:1]` → Empty list: `[]`

# %%
t = (1,2,3,4,5)
print(t[1:-1])
# Out:
# (2, 3, 4)

# %%
df1=pd.DataFrame(np.arange(9).reshape(3,3), columns=['a','b','c'], index=['one', 'two', 'three'])
df1
# Out:
#        a  b  c
# one    0  1  2
# two    3  4  5
# three  6  7  8

# %%
df2=pd.DataFrame(np.arange(6).reshape(-1,2), columns=['d','e'], index=['three', 'two', 'One'])
df2
# Out:
#        d  e
# three  0  1
# two    2  3
# One    4  5

# %%
pd.concat([df1, df2], axis=1)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  2.0  3.0
# three  6.0  7.0  8.0  0.0  1.0
# One    NaN  NaN  NaN  4.0  5.0

# %%
pd.concat([df1, df2], axis=0)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  NaN  NaN
# three  6.0  7.0  8.0  NaN  NaN
# three  NaN  NaN  NaN  0.0  1.0
# two    NaN  NaN  NaN  2.0  3.0
# One    NaN  NaN  NaN  4.0  5.0

# %%
nums = [1,2,3,4,5]
print(nums[:99:])  
dict = {'a': 1, 'b': 2, 'c': 3}
print(set(dict.keys()))
# Out:
# [1, 2, 3, 4, 5]
# {'b', 'a', 'c'}

# %%
df = pd.concat([df1, df2], axis=0)                # Stack rows vertically (default behavior), matching columns by name
print(df)
print(df.iloc[0:3])# First 3 rows from df1 (since df1 is on top) and all columns (including the new ones from df2)
print(df.iloc[0:3, 0:2])  # First 3 rows from df1 and first 2 columns (a and b)
print(df.iloc[1::, 0::-1])  #  All rows from index 1 onward and all columns from right to left
print(df.iloc[1::, 0:])  # All rows from index 1 onward and all columns (including the new ones from df2)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  NaN  NaN
# three  6.0  7.0  8.0  NaN  NaN
# three  NaN  NaN  NaN  0.0  1.0
# two    NaN  NaN  NaN  2.0  3.0
# One    NaN  NaN  NaN  4.0  5.0
#          a    b    c   d   e
# one    0.0  1.0  2.0 NaN NaN
# two    3.0  4.0  5.0 NaN NaN
# three  6.0  7.0  8.0 NaN NaN
#          a    b
# one    0.0  1.0
# two    3.0  4.0
# three  6.0  7.0
#          a
# two    3.0
# three  6.0
# three  NaN
# two    NaN
# One    NaN
#          a    b    c    d    e
# two    3.0  4.0  5.0  NaN  NaN
# three  6.0  7.0  8.0  NaN  NaN
# three  NaN  NaN  NaN  0.0  1.0
# two    NaN  NaN  NaN  2.0  3.0
# One    NaN  NaN  NaN  4.0  5.0

# %%
pd.concat([df1, df2], axis=1)                # Combine columns side-by-side, aligning rows by index (outer join by default)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  2.0  3.0
# three  6.0  7.0  8.0  0.0  1.0
# One    NaN  NaN  NaN  4.0  5.0

# %%
pd.concat([df1, df2], axis=1, join='outer')  # Side-by-side with all indexes included (union of indexes, may create NaNs)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  2.0  3.0
# three  6.0  7.0  8.0  0.0  1.0
# One    NaN  NaN  NaN  4.0  5.0

# %%
pd.concat([df1, df2], axis=1, join='inner')  # Side-by-side with only common indexes kept (intersection of indexes)
# Out:
#        a  b  c  d  e
# two    3  4  5  2  3
# three  6  7  8  0  1

# %%
pd.concat([df1, df2], axis=1, join='inner')
# Out:
#        a  b  c  d  e
# two    3  4  5  2  3
# three  6  7  8  0  1

# %% [markdown]
# ## `pd.merge()`

# %% [markdown]
# `pd.merge()` is a **Pandas function used to combine DataFrames based on common column(s) or key(s)** (similar to SQL joins).
#
# - **`on='col'`** → Column name used as the join key (must exist in both DataFrames).
# - **`left_on` / `right_on`** → Use different column names as join keys.
# - **`how='inner'`** → Keeps only matching rows (default).
# - **`how='left'`** → Keeps all rows from the left DataFrame.
# - **`how='right'`** → Keeps all rows from the right DataFrame.
# - **`how='outer'`** → Keeps all rows from both DataFrames.
#
# It is commonly used when combining datasets that share a common identifier (e.g., ID, email, product code).

# %%
df3=pd.DataFrame([['a','b','c'], ['d','e','f'],['g','h','i']], columns=['col1', 'col2', 'col3'])
df3
# Out:
#   col1 col2 col3
# 0    a    b    c
# 1    d    e    f
# 2    g    h    i

# %%
df4=pd.DataFrame([['x',1,'i'], ['e',2,'f'], ['b',3,'e'],['z',4,'h']], columns=['col2', 'col4', 'col5'])
df4
# Out:
#   col2  col4 col5
# 0    x     1    i
# 1    e     2    f
# 2    b     3    e
# 3    z     4    h

# %%
pd.merge(df3, df4, left_on='col2', right_on='col5', how='inner')  # Match df3['col2'] with df4['col5'], keep only matching rows
# Out:
#   col1 col2_x col3 col2_y  col4 col5
# 0    d      e    f      b     3    e
# 1    g      h    i      z     4    h

# %%
pd.merge(df3, df4, how='outer')            # Keep all rows from both DataFrames (union of keys, fills unmatched with NaN)
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c   3.0    e
# 1    d    e    f   2.0    f
# 2    g    h    i   NaN  NaN
# 3  NaN    x  NaN   1.0    i
# 4  NaN    z  NaN   4.0    h

# %%
pd.merge(df3, df4, how='inner')            # Keep only rows with matching keys in both DataFrames (intersection)
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c     3    e
# 1    d    e    f     2    f

# %%
pd.merge(df3, df4, on='col2', how='left')  # Keep all rows from df3, match on 'col2', fill unmatched df4 values with NaN
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c   3.0    e
# 1    d    e    f   2.0    f
# 2    g    h    i   NaN  NaN

# %%
pd.merge(df3, df4, left_on='col2', right_on='col5', how='inner')  # Match df3['col2'] with df4['col5'], keep only matching rows
# Out:
#   col1 col2_x col3 col2_y  col4 col5
# 0    d      e    f      b     3    e
# 1    g      h    i      z     4    h

# %%
pd.merge(df3, df4, on='col2', how='right') # Keep all rows from df4, match on 'col2', fill unmatched df3 values with NaN
# Out:
#   col1 col2 col3  col4 col5
# 0  NaN    x  NaN     1    i
# 1    d    e    f     2    f
# 2    a    b    c     3    e
# 3  NaN    z  NaN     4    h

# %%
df1 = pd.DataFrame({'key': [1, 2], 'A': ['x', 'y']})
df2 = pd.DataFrame({'key': [2, 3], 'B': ['w', 'z']})
res = pd.merge(df1, df2, on='key', how='outer')
res
# Out:
#    key    A    B
# 0    1    x  NaN
# 1    2    y    w
# 2    3  NaN    z

# %%
df1
# Out:
#    key  A
# 0    1  x
# 1    2  y

# %%
df2
# Out:
#    key  B
# 0    2  w
# 1    3  z

# %%
res
# Out:
#    key    A    B
# 0    1    x  NaN
# 1    2    y    w
# 2    3  NaN    z

# %%
res_concat_like_merge = (
    pd.concat(
        [df1.set_index("key"), df2.set_index("key")],
        axis=1,
        join="outer"
    )
    .reset_index()
)
res_concat_like_merge
# Out:
#    key    A    B
# 0    1    x  NaN
# 1    2    y    w
# 2    3  NaN    z

# %%
matrix = [[1, 2], [3, 4]]
print([num * 2 for row in matrix for num in row if num % 2 == 0])

arr1 = np.array([[1], [2], [3]])
arr2 = np.array([10, 20])
print((arr1 + arr2))
# Out:
# [4, 8]
# [[11 21]
#  [12 22]
#  [13 23]]

# %%
res_concat_like_merge = (
    pd.concat(
        [df1.set_index("key"), df2.set_index("key")],
        axis=0,
        join="outer"
    )
    .reset_index()

)
res_concat_like_merge
# Out:
#    key    A    B
# 0    1    x  NaN
# 1    2    y  NaN
# 2    2  NaN    w
# 3    3  NaN    z

# %%
import pandas as pd
df1 = pd.DataFrame({'id': [1, 2], 'val1': ['A', 'B']})
df2 = pd.DataFrame({'id': [2, 3], 'val2': ['C', 'D']})
res = pd.merge(df1, df2, on='id', how='left')
res
# Out:
#    id val1 val2
# 0   1    A  NaN
# 1   2    B    C

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3]})
df['A'] = df['A'].apply(lambda x: x**2)
print(df['A'].tolist())
# Out:
# [1, 4, 9]

# %%
df = pd.DataFrame({"A": [1,2,3]})
df["A"] = df["A"].apply(lambda k: k**2)
print(df)
# Out:
#    A
# 0  1
# 1  4
# 2  9

# %%
arr = np.array([1, 2, 4, 4, 5])
print(np.where(arr > 3, True, False))
print(arr[arr > 1])
# Out:
# [False False  True  True  True]
# [2 4 4 5]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': [1, np.nan, np.nan],
                   'B': [4, np.nan, 6],
                   'C': [7, np.nan, 9]})
print(df.dropna(how='all', axis=1))
print(df.dropna(how='all', axis=0))

print(df.iloc[0:3, 0:2])
# Out:
#      A    B    C
# 0  1.0  4.0  7.0
# 1  NaN  NaN  NaN
# 2  NaN  6.0  9.0
#      A    B    C
# 0  1.0  4.0  7.0
# 2  NaN  6.0  9.0
#      A    B
# 0  1.0  4.0
# 1  NaN  NaN
# 2  NaN  6.0

# %%
import pandas as pd
df1 = pd.DataFrame({'id': [1, 2], 'val1': ['A', 'B']})
df2 = pd.DataFrame({'id': [2, 3], 'val2': ['C', 'D']})
res = pd.merge(df1, df2, on='id', how='outer')
res
# Out:
#    id val1 val2
# 0   1    A  NaN
# 1   2    B    C
# 2   3  NaN    D

# %%
import pandas as pd

data = {
    'Dept': ['IT', 'IT', 'HR', 'HR', 'IT', 'HR'],
    'Year': [2023, 2024, 2023, 2024, 2023, 2023],
    'Sales': [100, 150, 200, 250, 50, 50]
}
df = pd.DataFrame(data)

print(df)
# Out:
#   Dept  Year  Sales
# 0   IT  2023    100
# 1   IT  2024    150
# 2   HR  2023    200
# 3   HR  2024    250
# 4   IT  2023     50
# 5   HR  2023     50

# %%
import pandas as pd
df1 = pd.DataFrame({'id': [1, 2], 'val1': ['A', 'B']})
df2 = pd.DataFrame({'id': [3, 4], 'val2': ['C', 'D']})
res = pd.merge(df1, df2, on='id', how='inner')
res
# Out:
# Empty DataFrame
# Columns: [id, val1, val2]
# Index: []

# %%
result = df.groupby(['Dept', 'Year'])[['Sales']].sum()
print(result)
# Out:
#            Sales
# Dept Year
# HR   2023    250
#      2024    250
# IT   2023    150
#      2024    150

# %%
import numpy as np
arr = np.arange(8).reshape(-1, 2)


arr
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5],
#        [6, 7]])

# %%
arr = np.arange(6).reshape(2, 3)
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
print({x: x**2 for x in (1, 2, 3)})
# Out:
# {1: 1, 2: 4, 3: 9}

# %%
t = (30, 20)          # Basic tuple with integers
print(t)
t = ("Apple", "Banana")   # Tuple of strings
t = (1, "Hello", 3.14)    # Mixed data types
t = 1, 2, 3               # "Packing": Parentheses are actually optional
t = (5,)                  # Singleton: MUST have a trailing comma for one item
empty = ()                # An empty tuple
# Out:
# (30, 20)

# %%
# Goal: Square every number in a list
nums = [1, 2, 3, 4]
squared = list(map(lambda x: x**2, nums)) 
print(squared)  # Output: [1, 4, 9, 16]

# Goal: Convert a list of strings to integers
prices = ["10", "20", "30"]
clean_prices = list(map(int, prices))
print(clean_prices)  # Output: [10, 20, 30]

# Goal: Capitalize names in a list
names = ["ALice", "bob", "charlie"]
caps = list(map(str.upper, names))
# Output: ['ALICE', 'BOB', 'CHARLIE']
print(caps)

list(zip([1, 2], ['a', 'b']))  # Output: [(1, 'a'), (2, 'b')]
# Out:
# [1, 4, 9, 16]
# [10, 20, 30]
# ['ALICE', 'BOB', 'CHARLIE']
# [(1, 'a'), (2, 'b')]

# %%
import pandas as pd
df1 = pd.DataFrame({'id': [1, 2], 'val1': ['A', 'B']})
df2 = pd.DataFrame({'id': [2, 3, 4], 'val2': ['C', 'D', 'E']})
res = pd.merge(df1, df2, on='id', how='right')
res
# Out:
#    id val1 val2
# 0   2    B    C
# 1   3  NaN    D
# 2   4  NaN    E

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': [1, np.nan, np.nan],
                   'B': [4, np.nan, 6],
                   'C': [7, np.nan, 9]})
print(df.dropna(how='all').shape)
print(df.dropna(how='all'))
df = pd.DataFrame({'A': [1, np.nan, np.nan], #these are columns
                   'B': [4, np.nan, 6],
                   'C': [7, np.nan, 9]})
df
# Out:
# (2, 3)
#      A    B    C
# 0  1.0  4.0  7.0
# 2  NaN  6.0  9.0
#      A    B    C
# 0  1.0  4.0  7.0
# 1  NaN  NaN  NaN
# 2  NaN  6.0  9.0

# %%
keys = ['a', 'b']
vals = [1, 2]
print(list(zip(keys,vals)))
# Out:
# [('a', 1), ('b', 2)]

# %%
s1 = {1, 2, 3}
s2 = {1, 2, 3}
print(s1.issubset(s2))
# Out:
# True

# %%
import pandas as pd
df1 = pd.DataFrame({'A': [1, 2, 3]})
df2 = pd.DataFrame({'B': [4, 5, 6]})
res = pd.concat([df1, df2], axis=0)
res
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  NaN
# 0  NaN  4.0
# 1  NaN  5.0
# 2  NaN  6.0

# %%
arr = np.array([[3, 8], [9, 2]])
print(arr.max(axis=1)) # across the columns
# Out:
# [8 9]

# %%
# CAREFUL
result = [x * 2 for x in range(5) if x % 2 == 0]
print(result)
# Out:
# [0, 4, 8]

# %%
import pandas as pd
data = {'city': ['NYC', 'LA', 'NYC', 'LA', 'NYC'],
        'sales': [100, 200, 150, 300, 50]}
df = pd.DataFrame(data)
print(df.groupby('city')['sales'].sum())
# Out:
# city
# LA     500
# NYC    300
# Name: sales, dtype: int64

# %%
cond = np.array([True, False, True])
print(np.where(cond, [1, 2, 3], [4, 5, 6]))
# Out:
# [1 5 3]

# %%
d = {'x': [10, 20], 'y': [30, 40], 'z': [50, 60]}
import pandas as pd
df = pd.DataFrame(d)
print(df.shape)
# Out:
# (2, 3)

# %%
lst = [5, 10, 15, 20, 25]
lst.extend([10,20])
print(lst.count(10))
print(lst)
# Out:
# 2
# [5, 10, 15, 20, 25, 10, 20]

# %%
lst = [5, 10, 15, 20, 25]
lst.append([10,20])
print(lst.count(10))
print(lst)
# Out:
# 1
# [5, 10, 15, 20, 25, [10, 20]]

# %%
import pandas as pd
df1 = pd.DataFrame({'id': [1, 2, 2], 'val': ['A', 'B', 'C']})
df2 = pd.DataFrame({'id': [2, 3], 'score': [100, 200]})
res = pd.merge(df1, df2, on='id', how='inner')
print(res)
print(df1)
print(df2)
# Out:
#    id val  score
# 0   2   B    100
# 1   2   C    100
#    id val
# 0   1   A
# 1   2   B
# 2   2   C
#    id  score
# 0   2    100
# 1   3    200

# %%
df1 = pd.DataFrame({'id': [1, 1], 'val': ['A', 'B']})
df2 = pd.DataFrame({'id': [1, 1], 'score': [10, 20]})
res = pd.merge(df1, df2, on='id', how='inner')
print((res.shape))
print(res)
# Out:
# (4, 3)
#    id val  score
# 0   1   A     10
# 1   1   A     20
# 2   1   B     10
# 3   1   B     20

# %%
d = {"a": 100, "b": 200}
print("a" in d.keys())
print(d["a"])
print(d.get("a"))
print(d.get("c", None))
# Out:
# True
# 100
# 100
# None
