# %%
# read the content of the file ../data/chat.txt
# !cat ../data/chat.txt
f=open('../data/chat.txt')
content=f.read()
f.close()

# %%
# find the total number of participants in this chat
# print(content)
# set([l.split()[0] for l in content.strip().split('\n')[::2]])
# import re
# [n[:-2]for n in re.findall("[A-Z][a-z]+ \\d",content)]
# !cat ../data/chat.txt | grep ":" | cut -d' ' -f1 | sort | uniq
# Out:
# Daniel
# Elizabeth
# Emily
# Emma
# Jack
# Jayden
# John
# Mary
# Michael
# William

# %%
 # find the one who partipated most
# !cat ../data/chat.txt | grep ":" | cut -d' ' -f1 | sort | uniq -c | sort -nr
# Out:
#     122 Emily
#      99 John
#      98 Michael
#      91 William
#      90 Jack
#      89 Elizabeth
#      87 Emma
#      86 Mary
#      83 Jayden
#      77 Daniel

# %%
# find the duration of the chat

# %%
# find the topic these people were talking about (i.e find the most frequent_words)
