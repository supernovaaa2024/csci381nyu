# %%
import requests
content= requests.get('https://www.usatoday.com/').text
type(content)
# Out:
# str

# %%
# pip install bs4

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(content)

# %%
soup.find_all('a')[4].text
# soup.find_all('img')[0]
# Out:
# 'Check home prices 🏠'

# %%
import requests
from bs4 import BeautifulSoup
content= requests.get('https://www.usatoday.com/').text
soup=BeautifulSoup(content)
news=[t.text for t in soup.find_all('a',{'class':'gnt_m_th_a'})]
f=open('news.txt', 'a')
f.write('\n'.join(news))
f.close()

# %%
news=[t.text for t in soup.find_all('a',{'class':'gnt_m_th_a'})]
links=[t['href'] for t in soup.find_all('a',{'class':'gnt_m_th_a'})]

print('\n'.join(news))
print('----------------------------------')
print('\n'.join(links))
# Out:
# Oil prices soar; Trump says US can fight 'forever': Iran war updates
# Primary election updates: 2026 midterms kick off in three states
# Iran war death toll so far: 6 US service members killed
# Voting time: Texas, Arkansas, North Carolina begin the 2026 primaries
# Noem grilled on ICE, Minnesota at Senate hearing: Recap
# Gas tops $3 a gallon as oil prices surge amid widening Iran war
# 'Open betrayal.' MAGA clashes with Trump on Iran.
# ‘Draft Barron Trump’ calls for Barron to join US strikes in Iran
# ----------------------------------
# /live-story/news/politics/2026/03/03/iran-us-israel-war-live-updates/88956478007/
# /live-story/news/politics/2026/03/03/primary-election-live-updates-texas-nc-arkansas/88709965007/
# /story/news/world/2026/03/03/iran-war-death-toll-us-middle-east/88957603007/
# /story/news/politics/2026/03/03/texas-arkansas-north-carolina-midterm-primaries-march-3/88880833007/
# /live-story/news/politics/2026/03/03/kristi-noem-senate-hearing-live-updates/88957893007/
# /story/money/energy/2026/03/03/gas-oil-prices-rise-iran-war/88958628007/
# /story/news/politics/2026/03/02/donald-trump-maga-steve-bannon-iran-iraq-war/88950411007/
# /story/news/politics/2026/03/03/draft-barron-trump-website-parody-us-strikes-iran/88958422007/

# %%
! which python
# Out:
# /opt/conda/bin/python

# %%
# soup.find_all('a',{'class':'gnt_m_th_a'})[0].text
soup.find_all('a',{'class':'gnt_m_th_a'})[0]['href']
# Out:
# '/live-story/news/politics/2026/03/03/iran-us-israel-war-live-updates/88956478007/'

# %%
keywords=' '.join(news).lower().replace('.','').replace(',','').split()
d={}
for w in keywords:
    if w not in d:
        d[w]=1
    else:
        d[w]+=1

# %%
from collections import Counter
# sorted(dict(Counter(keywords)).items(), key=lambda t:t[1])[::-1]
Counter(keywords)
# Out:
# Counter({'iran': 5,
#          'us': 3,
#          'war': 3,
#          'oil': 2,
#          'prices': 2,
#          'trump': 2,
#          '2026': 2,
#          'in': 2,
#          'on': 2,
#          'barron': 2,
#          'soar;': 1,
#          'says': 1,
#          'can': 1,
#          'fight': 1,
#          "'forever':": 1,
#          'updates': 1,
#          'primary': 1,
#          'election': 1,
#          'updates:': 1,
#          'midterms': 1,
#          'kick': 1,
#          'off': 1,
#          'three': 1,
#          'states': 1,
#          'death': 1,
#          'toll': 1,
#          'so': 1,
#          'far:': 1,
#          '6': 1,
#          'service': 1,
#          'members': 1,
#          'killed': 1,
#          'voting': 1,
#          'time:': 1,
#          'texas': 1,
#          'arkansas': 1,
#          'north': 1,
#          'carolina': 1,
#          'begin': 1,
#          'the': 1,
#          'primaries': 1,
#          'noem': 1,
#          'grilled': 1,
#          'ice': 1,
#          'minnesota': 1,
#          'at': 1,
#          'senate': 1,
#          'hearing:': 1,
#          'recap': 1,
#          'gas': 1,
#          'tops': 1,
#          '$3': 1,
#          'a': 1,
#          'gallon': 1,
#          'as': 1,
#          'surge': 1,
#          'amid': 1,
#          'widening': 1,
#          "'open": 1,
#          "betrayal'": 1,
#          'maga': 1,
#          'clashes': 1,
#          'with': 1,
#          '‘draft': 1,
#          'trump’': 1,
#          'calls': 1,
#          'for': 1,
#          'to': 1,
#          'join': 1,
#          'strikes': 1})
