# %% [markdown]
# # Unix Shell & Command-Line Reference Notebook

# %% [markdown]
# ## 1. Shell Basics
#
# A **shell** is a command-line interface between the user and the operating system.

# %%
echo $SHELL       # Display the path of the current user's default shell

cat /etc/shells   # Show all available shells installed on the system
# Out:
# /bin/zsh
# # List of acceptable shells for chpass(1).
# # Ftpd will not allow users to connect who are not using
# # one of these shells.
#
# /bin/bash
# /bin/csh
# /bin/dash
# /bin/ksh
# /bin/sh
# /bin/tcsh
# /bin/zsh

# %% [markdown]
# ## 2. Remote Connections (SSH)
#
# - Connect: `ssh -Y username@access.cims.nyu.edu`
# - Disconnect: `~.` (type after pressing Enter)

# %% [markdown]
# ## 3. System & Utility Commands
#
# | Command | Purpose |
# |------|--------|
# | history | command history |
# | clear | clear screen |
# | uname -a | system info |
# | shutdown -h now | halt |
# | shutdown -r | reboot |

# %%
uname -a      # Display detailed system information (kernel, OS, architecture, hostname, etc.)
history       # Show the command history of the current shell session
# Out:
# Darwin Owens-MacBook-Pro.local 25.3.0 Darwin Kernel Version 25.3.0: Wed Jan 28 20:54:22 PST 2026; root:xnu-12377.81.4~5/RELEASE_ARM64_T6030 arm64
#   447  __DW_OUTPUT_FORMATTER_CACHE__ = __DW_SCOPE__.get("output_cache", {})
#   448  __DW_SCOPE__["output_cache"] = __DW_OUTPUT_FORMATTER_CACHE__
#   449  __DW_OUTPUT_FORMATTER_API__ = {
#   450      "output_cache": __DW_OUTPUT_FORMATTER_CACHE__,
#   451      "io": __DW_IO__(__DW_OUTPUT_FORMATTER_ID__, async_type="display"),
#   452      "pandas_transport": __DW_PANDAS_TRANSPORT__(),
#   453      "pandas_converter": __DW_CONVERT_TO_PANDAS__,
#   454  }
#   455  __DW_OUTPUT_FORMATTER__ = __DW_OUTPUT_FORMATTER__(__DW_OUTPUT_FORMATTER_API__)
#   456  __DW_SCOPE__[__DW_OUTPUT_FORMATTER_ID__] = __DW_OUTPUT_FORMATTER__
#   457  __DW_OUTPUT_FORMATTER__["enable_for_types"]("pandas.core.frame.DataFrame", "pandas.core.series.Series")
#   458  import builtins as __DW_BUILTINS__
#   459  __DW_BUILTINS__.print(__DW_OUTPUT_FORMATTER_ID__)
#   460  del __DW_BUILTINS__
#   461  del __DW_OUTPUT_FORMATTER_ID__
#   462  del __DW_IO__
#   463  del __DW_GET_SESSION_ID__
#   464  del __DW_OUTPUT_FORMATTER_CACHE__
#   465  del __DW_PANDAS_TRANSPORT__
#   466  del __DW_CONVERT_TO_PANDAS__
#   467  del __DW_OUTPUT_FORMATTER__
#   468  del __DW_OUTPUT_FORMATTER_API__
#   469  { echo $?; } 2>/dev/null
#   470  echo $SHELL       # Display the path of the current user's default shell
#   471  cat /etc/shells   # Show all available shells installed on the system
#   472  { echo $?; } 2>/dev/null
#   473  uname -a      # Display detailed system information (kernel, OS, architecture, hostname, etc.)
#   474  history       # Show the command history of the current shell session
#   475  { echo $?; } 2>/dev/null
#   476  ls        # List files and directories in the current directory
#   477  ls -l     # List files and directories in long format (permissions, owner, size, date)
#   478  ls -a     # List all files, including hidden files (those starting with .)
#   479  ls -la    # Long format listing including hidden files
#   480  { echo $?; } 2>/dev/null
#   481  echo -e "hi\nwelcome"
#   482  { echo $?; } 2>/dev/null
#   483  echo -e "a\nb\nc\nd" > sample.txt
#   484  { echo $?; } 2>/dev/null
#   485  cat sample.txt        # Display the entire contents of the file in the terminal
#   486  nl sample.txt         # Display the file contents with line numbers added
#   487  head -n 2 sample.txt  # Show only the first 2 lines of the file
#   488  tail -n 2 sample.txt  # Show only the last 2 lines of the file
#   489  tail -n +2 sample.txt # Show the file starting from line 2 to the end
#   490  stat sample.txt       # Display detailed file metadata (size, permissions, timestamps, inode)
#   491  { echo $?; } 2>/dev/null
#   492  PS1='PROMPT_EFZNIWEJNLCD\[\]>' PS2='PROMPT_EFZNIWEJNLCD\[\]+' PROMPT_COMMAND=''
#   493  export PAGER=cat
#   494  bind 'set enable-bracketed-paste off' >/dev/null 2>&1 || true
#   495  display () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved image data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   496  displayHTML () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved html data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   497  displayJS () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved javascript data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   498  export NOTEBOOK_BASH_KERNEL_CAPABILITIES="image,html,javascript"
#   499  PS1='PROMPT_ADCHQDEVZVSQ\[\]>' PS2='PROMPT_ADCHQDEVZVSQ\[\]+' PROMPT_COMMAND=''
#   500  export PAGER=cat
#   501  bind 'set enable-bracketed-paste off' >/dev/null 2>&1 || true
#   502  display () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved image data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   503  displayHTML () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved html data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   504  displayJS () {     display_id="$1"; shift;     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     prefix="bash_kernel: saved javascript data to: ";     if [[ "${display_id}" != "" ]]; then         echo "${prefix}(${display_id}) $TMPFILE" >&2;     else         echo "${prefix}$TMPFILE" >&2;     fi; }
#   505  export NOTEBOOK_BASH_KERNEL_CAPABILITIES="image,html,javascript"
#   506  import builtins as __DW_BUILTINS_FOR_SCOPE__
#   507  __DW_SCOPE__ = __DW_BUILTINS_FOR_SCOPE__.globals().get("__DW_SCOPE__", {})
#   508  __DW_BUILTINS_FOR_SCOPE__.globals()["__DW_SCOPE__"] = __DW_SCOPE__
#   509  del __DW_BUILTINS_FOR_SCOPE__
#   510  def __DW_GET_SESSION_ID__():
#   511      import uuid
#   512      from builtins import str
#   513      session_id = str(uuid.uuid4())
#   514      return session_id
#   515  """
# Note: all executions are function-scoped as we do not assume the code below executes in an isolated kernel environment.
# """
#   516  def __DW_IO__(session_id, async_type=None):
#   517      from builtins import dict, Exception, isinstance, object, str
#   518      DW_OUTPUT_MIME_TYPE = "application/vnd.microsoft.datawrangler.output+json"
#   519      def comm():
#   520          from comm import create_comm
#   521          comm = create_comm("datawrangler")
#   522          return lambda msg: comm.send(msg, {"async": True})
#   523
#   524      def display():
#   525          from IPython.display import DisplayHandle
#   526          handle = DisplayHandle()
#   527          handle.display({ DW_OUTPUT_MIME_TYPE: {} }, raw=True)
#   528          return lambda msg: handle.update({ DW_OUTPUT_MIME_TYPE: msg }, raw=True, metadata={"async": True})
#   529      types = {
#   530          "comm": comm,
#   531          "display": display,
#   532      }
#   533      send_async_output = None
#   534      if async_type in types:;         try:;             send_async_output = types[async_type]()
#   535          except Exception:
#   536              pass
#   537
#   538      def output_mime(data):
#   539          import sys
#   540          class MimeBundle(object):
#   541              def __init__(self, data):
#   542                  self.data = data
#   543              def _repr_mimebundle_(self, **kwargs):
#   544                  return { "text/plain": "", **self.data }
#   545              # 'text/plain' may be added to the bundle automatically. Make sure it does not take up space.
#   546              def __str__(self):
#   547                  return ""
#   548              def __repr__(self):
#   549                  return ""
#   550          sys.displayhook(MimeBundle(data))
#   551
#   552      def output(data):
#   553          # vscode-jupyter has a problem handling non-object JSON at the top level. So make sure we never send it.
#   554          if not isinstance(data, dict):
#   555              raise Exception("Output data must be a dictionary")
#   556          output_mime({ DW_OUTPUT_MIME_TYPE: data })
#   557      def output_async(**data):
#   558          msg = {"_session": session_id, **data}
#   559          if send_async_output:;             send_async_output(msg)
#   560
#   561      def log_exception(error_details=None, props={}, measures={}):
#   562          if error_details is not None:;             errorName = error_details["name"];             error = error_details["message"];         else:;             import sys;             (errorName, error) = sys.exc_info()[:2]
#   563          output_async(type="error", name=str(errorName), message=str(error), properties=props, measures=measures)
#   564
#   565      def log_telemetry(name, props={}, measures={}):
#   566          output_async(type="telemetry", event=name, properties=props, measurements=measures)
#   567      return dict(
#   568          output=output,
#   569          output_async=output_async,
#   570          log_exception=log_exception,
#   571          log_telemetry=log_telemetry,
#   572      )
#   573  def __DW_PANDAS_TRANSPORT__():
#   574      from builtins import any, AttributeError, bool, dict, Exception, hasattr, ImportError, isinstance, len, list, map, min, object, range, str, tuple, type
#   575      def get_df_shape(df):
#   576          shape = {}
#   577          shape["rows"], shape["columns"] = df.shape
#   578          return shape
#   579      def get_index_column_name(df):
#   580          try:
#   581              index_column_name = df.index.name if df.index.name else str(tuple(df.index.names)) if len(df.index.names) > 1 else "index"
#   582          except AttributeError:
#   583              index_column_name = "index"
#   584          return index_column_name
#   585      def get_inferred_dtype(column):
#   586          import pandas as pd
#   587          # In some older versions of Pandas, infer_dtype does not support sparse columns
#   588          if hasattr(column, "sparse"):
#   589              column = column.sparse.to_dense()
#   590          inferred_dtype = pd.api.types.infer_dtype(column, skipna=True)
#   591          return inferred_dtype
#   592      def map_dtype_to_dw_type(dtype, inferred_dtype=None):
#   593          """
#         References to known types:
#         - Pandas: https://stackoverflow.com/a/29246498
#         - NumPy: https://numpy.org/doc/stable/reference/arrays.scalars.html
#
#         Note: the types here do not necessarily include all NumPy types, but rather
#         what type Pandas uses when the type is used as input. For example, NumPy
#         supports several precision for datetimes, while Pandas internally only uses
#         nanoseconds, see https://github.com/pandas-dev/pandas/issues/6741#issuecomment-39026803
#
#         Note that the value mapped here is used for the following purposes:
#         - To figure out what "picker" should be used for this type in the UI, e.g. when replacing
#         - To figure out what operations should be associated with this type in the UI
#         """
#   594          import re
#   595          # string types
#   596          if dtype == "string" or (dtype == "object" and inferred_dtype == "string"):
#   597              return "string"
#   598          # category types
#   599          # TODO@DW: enable this
#   600          # if dtype == "category":
#   601          #     return "category"
#   602          # float types
#   603          # TODO@DW: consider if we need to distinguish nullable types
#   604          # or pass it along as metadata for certain operations
#   605          if re.fullmatch(r"(?:float|Float)\d+", dtype):
#   606              return "float"
#   607          # int types
#   608          # TODO@DW: consider if we need to distinguish nullable types
#   609          # or pass it along as metadata for certain operations
#   610          if re.fullmatch(r"(?:int|uint|Int|UInt)\d+", dtype):
#   611              return "integer"
#   612          # complex types
#   613          # TODO@DW: enable this
#   614          # if re.fullmatch("complex\d+", dtype):
#   615          #     return "complex"
#   616          # boolean types
#   617          # TODO@DW: consider if we need to distinguish nullable types
#   618          # or pass it along as metadata for certain operations
#   619          if dtype in ["bool", "boolean"]:;             return "boolean";
#         if dtype == "datetime64[ns]":;             return "datetime";
#         return "unknown";      def is_missing(value):
#   620          import pandas as pd
#   621          return pd.api.types.is_scalar(value) and bool(pd.isna(value))
#   622      def serialize(x):
#   623          if is_missing(x):
#   624              return None
#   625          return str(x)
#   626      def serialize_row(df, idx):
#   627          key = df.index[idx]
#   628          data = [serialize(key), *(serialize(df.iat[idx, col]) for col in range(len(df.columns)))]
#   629          return data
#   630      def pd_dumps(data):
#   631          try:
#   632              # This was renamed in Pandas 2.2.0. We need to try both.
#   633              from pandas.io.json import ujson_dumps as pd_dumps
#   634          except ImportError:
#   635              from pandas.io.json import dumps as pd_dumps
#   636          return pd_dumps(data, iso_dates=True, default_handler=str)
#   637
#   638      def get_df_payload_v0(df, row_limit, **extra_props):
#   639          import pandas as pd
#   640          data = []
#   641          for i in range(0, min(len(df), row_limit)):
#   642              data.append(serialize_row(df, i))
#   643          column_types = [df.index.dtype] + list(df.dtypes)
#   644          column_names = [get_index_column_name(df)] + list(df)
#   645          columns = [df.index] + [df.iloc[:, column_idx] for column_idx in range(len(list(df)))]
#   646          column_info_list = []
#   647          for column_idx in range(0, len(column_names)):
#   648              column_info = {}
#   649              # for each column, figure out the type and name
#   650              raw_column_type = str(column_types[column_idx])
#   651              column_name = column_names[column_idx]
#   652              column = columns[column_idx]
#   653              column_info["name"] = str(column_name)
#   654              column_info["rawType"] = raw_column_type
#   655              column_info["type"] = map_dtype_to_dw_type(raw_column_type, "string" if pd.api.types.is_string_dtype(column) else None)
#   656              column_info_list.append(column_info)
#   657          return pd_dumps({
#   658              **extra_props,
#   659              "shape": get_df_shape(df),
#   660              "rows": data,
#   661              "columns": column_info_list
#   662          })
#   663      def get_df_payload(df, row_limit, **extra_props):
#   664          return get_df_payload_v0(df, row_limit, **extra_props)
#   665      # namespace exports
#   666      return dict(
#   667          is_missing=is_missing,
#   668          get_df_shape=get_df_shape,
#   669          get_index_column_name=get_index_column_name,
#   670          get_inferred_dtype=get_inferred_dtype,
#   671          map_dtype_to_dw_type=map_dtype_to_dw_type,
#   672          serialize=serialize,
#   673          serialize_row=serialize_row,
#   674          pd_dumps=pd_dumps,
#   675          get_df_payload=get_df_payload
#   676      )
#   677  def __DW_CONVERT_TO_PANDAS__(data_type, data):
#   678      from builtins import Exception, type
#   679      import sys
#   680      df = None
#   681      conversion_method = None
#   682      try:
#   683          if "xarray" in sys.modules:;             if data_type == "xarray.core.dataarray.DataArray":;                 import pandas as pd;                 data_numpy = data.to_numpy()
#   684                  df = pd.DataFrame(data_numpy.tolist() if len(data_numpy.shape) > 2 else data_numpy)
#   685          if data_type == "builtins.dict":;             def convert_dict_to_pandas(data):
#   686                  from builtins import Exception, any, isinstance, len, list, map, print, tuple
#   687                  import numpy as np
#   688                  import pandas as pd
#   689                  nonlocal conversion_method
#   690                  conversion_method = "PandasFromDictOrientIndex"
#   691                  try:
#   692                      if not any(map(lambda x: isinstance(x, (list, tuple, np.ndarray)), data.values())):
#   693                          df = pd.DataFrame.from_dict(data, orient='index')
#   694                          return df
#   695                  except Exception:
#   696                      pass
#   697                  conversion_method = "PandasFromDictOrientColumns"
#   698                  try:
#   699                      df = pd.DataFrame.from_dict(data)
#   700                      return df
#   701                  except Exception:
#   702                      pass
#   703                  conversion_method = "DictToDataFrameWide"
#   704                  def import_dict_value(v):
#   705                      if not isinstance(v, (list, tuple, np.ndarray, pd.Series)):
#   706                          return [v]
#   707                      else:
#   708                          v_numpy = np.empty(len(v), dtype=object)
#   709                          v_numpy[:] = list(v)
#   710                          return np.array(v_numpy, dtype=object)
#   711
#   712                  df = pd.DataFrame.from_dict({
#   713                      k: import_dict_value(v) for k, v in data.items()
#   714                  }, orient="index").transpose().fillna(value=np.nan)
#   715                  return df
#   716
#   717              df = convert_dict_to_pandas(data)
#   718          if "tensorflow" in sys.modules:;             if data_type == "tensorflow.python.framework.ops.EagerTensor":;                 import pandas as pd;                 data_numpy = data.numpy()
#   719                  df = pd.DataFrame(data_numpy.tolist() if len(data_numpy.shape) > 2 else data_numpy)
#   720          if data_type == "builtins.list":;             def convert_list_to_pandas(data):
#   721                  from builtins import Exception, hasattr, len, print
#   722                  import numpy as np
#   723                  import pandas as pd
#   724                  import sys
#   725                  nonlocal conversion_method
#   726                  conversion_method = "PandasDataFrameConstructor"
#   727                  try:
#   728                      df = pd.DataFrame(data)
#   729                      return df
#   730                  except Exception:
#   731                      pass
#   732                  conversion_method = "NumpyArrayTorchNoGrad"
#   733                  try:
#   734                      if 'torch' in sys.modules and hasattr(sys.modules['torch'], 'no_grad'):
#   735                          import torch
#   736                          with torch.no_grad():
#   737                              df = pd.DataFrame(np.array(data))
#   738                          return df
#   739                  except Exception:
#   740                      pass
#   741                  conversion_method = "NumpyArrayWithObjectDtypeTorchNoGrad"
#   742                  try:
#   743                      if 'torch' in sys.modules and hasattr(sys.modules['torch'], 'no_grad'):
#   744                          import torch
#   745                          with torch.no_grad():
#   746                              data_numpy = np.empty(len(data), dtype=object)
#   747                              data_numpy[:] = data
#   748                              df = pd.DataFrame(np.array(data_numpy, dtype=object))
#   749                          return df
#   750                  except Exception:
#   751                      pass
#   752                  conversion_method = "NumpyArray"
#   753                  try:
#   754                      df = pd.DataFrame(np.array(data))
#   755                      return df
#   756                  except Exception:
#   757                      pass
#   758                  conversion_method = "NumpyArrayWithObjectDtype"
#   759                  data_numpy = np.empty(len(data), dtype=object)
#   760                  data_numpy[:] = data
#   761                  df = pd.DataFrame(np.array(data_numpy, dtype=object))
#   762                  return df
#   763
#   764              df = convert_list_to_pandas(data)
#   765          if "numpy" in sys.modules:;             if data_type == "numpy.ndarray":;                 def convert_ndarray_to_pandas(data):
#   766                      from builtins import Exception, len, print
#   767                      import pandas as pd
#   768                      nonlocal conversion_method
#   769                      conversion_method = "PandasDataFrameConstructor"
#   770                      try:
#   771                          df = pd.DataFrame(data)
#   772                          return df
#   773                      except Exception:
#   774                          pass
#   775                      conversion_method = "FlattenDimensions"
#   776                      df = pd.DataFrame(data.tolist())
#   777                      return df
#   778
#   779                  df = convert_ndarray_to_pandas(data)
#   780          if "pandas" in sys.modules:;             if data_type == "pandas.core.frame.DataFrame":;                 df = data;         if "pandas" in sys.modules:;             if data_type == "pandas.core.series.Series":;                 df = data.to_frame()
#   781          if "polars" in sys.modules:;             if data_type == "polars.dataframe.frame.DataFrame":;                 df = data.to_pandas()
#   782          if "polars" in sys.modules:;             if data_type == "polars.series.series.Series":;                 df = data.to_pandas().to_frame()
#   783          if "pyspark" in sys.modules:;             if data_type == "pyspark.sql.dataframe.DataFrame":;                 df = data.toPandas()
#   784          if "pyspark" in sys.modules:;             if data_type == "pyspark.sql.dataframe.DataFrame":;                 df = data.toPandas()
#   785          if "torch" in sys.modules:;             if data_type == "torch.Tensor":;                 import pandas as pd;                 data_tmp = data.detach().cpu()
#   786                  data_tmp = data_tmp.to_dense() if data_tmp.is_sparse else data_tmp
#   787                  data_numpy = data_tmp.numpy()
#   788                  df = pd.DataFrame(data_numpy.tolist() if len(data_numpy.shape) > 2 else data_numpy)
#   789          return df, conversion_method
#   790      except Exception:
#   791          return None, conversion_method
#   792  def __DW_OUTPUT_FORMATTER__(api):
#   793      import IPython
#   794      import traitlets
#   795      import traceback
#   796      from builtins import classmethod, dict, Exception, ImportError, list, set, str, type
#   797      DW_JSON_MIME_TYPE = 'application/vnd.microsoft.datawrangler.viewer.v0+json'
#   798      max_num_rows_to_preload = 50
#   799      tmp_vars = api["output_cache"]
#   800      io = api["io"]
#   801      supported_types = set()
#   802      class DataWranglerFormatter(IPython.core.formatters.BaseFormatter):
#   803          format_type = traitlets.Unicode(DW_JSON_MIME_TYPE)
#   804          print_method = traitlets.ObjectName('_repr_dw_')
#   805      class DataWrangler(IPython.display.DisplayObject):
#   806          """
#         Data Wrangler formatter.
#         """
#   807          is_supported = False
#   808          def __init__(self, expr_val):
#   809              import time
#   810              start_time = time.time()
#   811              props = {}
#   812              try:
#   813                  nonlocal supported_types
#   814                  type_str = type_to_str(type(expr_val))
#   815                  pandas_supported = is_pandas_supported()
#   816                  if pandas_supported and type_str in supported_types:;                     pandas_df, conversion_method = api["pandas_converter"](type_str, expr_val)
#   817                      self.is_supported = pandas_df is not None
#   818                  # Base telemetry props
#   819                  props = { "type": type_str, "conversionMethod": conversion_method, "supportedTypes": list(supported_types) }
#   820                  if self.is_supported:;                     import uuid;                     self.id = str(uuid.uuid4())
#   821                      # create a shallow copy in case a displayed object is mutated in the same cell
#   822                      if pandas_df is expr_val:;                         pandas_df = pandas_df.copy(deep=False)
#   823                      tmp_vars[self.id] = {
#   824                          "original": expr_val,
#   825                          "converted": pandas_df,
#   826                          "conversion_method": conversion_method,
#   827                          "original_type": type_str,
#   828                      }
#   829                      io["log_telemetry"](name="OutputConverted", props=props, measures={"conversionTime": time.time() - start_time})
#   830                  elif type_str in supported_types:
#   831                      props["isPandasSupported"] = pandas_supported
#   832                      io["log_exception"](
#   833                          error_details={
#   834                              "name": "OutputConversionError",
#   835                              "message": "Failed to convert"
#   836                          },
#   837                          props=props,
#   838                          measures={"conversionTime": time.time() - start_time}
#   839                      )
#   840                  else:
#   841                      # This can be called for subclasses, so we don't actually want to log them to avoid PII.
#   842                      # We just want to check here if we're failing because we don't have pandas or it's a subtype.
#   843                      del props["type"]
#   844                      props["isPandasSupported"] = pandas_supported
#   845                      io["log_telemetry"](name="OutputConversionSkipped", props=props, measures={"conversionTime": time.time() - start_time})
#   846              except Exception:
#   847                  # We shouldn't receive errors here, but if we do we can send telemetry for it.
#   848                  io["log_exception"](
#   849                      props=props,
#   850                      measures={"conversionTime": time.time() - start_time}
#   851                  )
#   852          @classmethod
#   853          def formatter(cls, var, **kwargs):
#   854              s = cls(var, **kwargs)
#   855              return s._repr_dw_()
#   856          def _repr_mimebundle_(self):
#   857              mime_bundle = {}
#   858              try:
#   859                  if self.is_supported:;                     mime_bundle[DW_JSON_MIME_TYPE] = self._gen_json()
#   860              except Exception:
#   861                  # need to catch and print exception since it is user visible
#   862                  traceback.print_exc()             return mime_bundle
#   863          def _repr_dw_(self):
#   864              try:
#   865                  return self._gen_json()
#   866              except Exception:
#   867                  # need to catch and print exception since it is user visible
#   868                  traceback.print_exc()         def _gen_json(self):
#   869              if self.is_supported:;                 kwargs = {"ref": self.id};                 return api["pandas_transport"]["get_df_payload"](tmp_vars[self.id]["converted"], max_num_rows_to_preload, **kwargs)
#   870      def register_dw_mimetype():
#   871          """Register _repr_dw_ with the IPython display mechanism."""
#   872          shell = IPython.get_ipython()
#   873          if not shell:;             return;         display_formatter = shell.display_formatter;         display_formatter.formatters.setdefault(
#   874              DW_JSON_MIME_TYPE,
#   875              DataWranglerFormatter(parent=display_formatter),
#   876          )
#   877      def enable_formatter_for_types(*args):
#   878          """
#         Enables Data Wrangler as the default IPython formatter for the given type.
#         """
#   879          nonlocal supported_types
#   880          supported_types = set()
#   881          register_dw_mimetype()         formatters = IPython.get_ipython().display_formatter.formatters
#   882          for arg in args:;             supported_types.add(type_to_str(arg) if type(arg) == type else arg)
#   883              if type(arg) == str:
#   884                  try:
#   885                      path, base = arg.rsplit(".", 1)
#   886                  except Exception:
#   887                      path = "builtins"
#   888                      base = arg
#   889                  formatters[DW_JSON_MIME_TYPE].for_type_by_name(
#   890                      path, base, DataWrangler.formatter
#   891                  )
#   892              else:
#   893                  formatters[DW_JSON_MIME_TYPE].for_type(
#   894                      arg, DataWrangler.formatter
#   895                  )
#   896      def disable_formatter():
#   897          """
#         Disables the formatter.
#         """
#   898          nonlocal supported_types
#   899          formatters = IPython.get_ipython().display_formatter.formatters
#   900          supported_types = []
#   901          for key in list(formatters.keys()):
#   902              # Only explicitly disable the MIME type we are registered with.
#   903              # This will allow us to run with several MIME type versions concurrently.
#   904              if key == DW_JSON_MIME_TYPE:;                 formatters.pop(key)
#   905      def type_to_str(type):
#   906          return f'{type.__module__}.{type.__qualname__}'
#   907      def is_pandas_supported():
#   908          try:
#   909              import pandas as _
#   910              return True
#   911          except ImportError:
#   912              return False
#   913      # namespace exports
#   914      return dict(
#   915          enable_for_types=enable_formatter_for_types,
#   916          disable=disable_formatter
#   917      )
#   918  __DW_OUTPUT_FORMATTER_ID__ = "output-" + __DW_GET_SESSION_ID__()
#   919  __DW_OUTPUT_FORMATTER_CACHE__ = __DW_SCOPE__.get("output_cache", {})
#   920  __DW_SCOPE__["output_cache"] = __DW_OUTPUT_FORMATTER_CACHE__
#   921  __DW_OUTPUT_FORMATTER_API__ = {
#   922      "output_cache": __DW_OUTPUT_FORMATTER_CACHE__,
#   923      "io": __DW_IO__(__DW_OUTPUT_FORMATTER_ID__, async_type="display"),
#   924      "pandas_transport": __DW_PANDAS_TRANSPORT__(),
#   925      "pandas_converter": __DW_CONVERT_TO_PANDAS__,
#   926  }
#   927  __DW_OUTPUT_FORMATTER__ = __DW_OUTPUT_FORMATTER__(__DW_OUTPUT_FORMATTER_API__)
#   928  __DW_SCOPE__[__DW_OUTPUT_FORMATTER_ID__] = __DW_OUTPUT_FORMATTER__
#   929  __DW_OUTPUT_FORMATTER__["enable_for_types"]("pandas.core.frame.DataFrame", "pandas.core.series.Series")
#   930  import builtins as __DW_BUILTINS__
#   931  __DW_BUILTINS__.print(__DW_OUTPUT_FORMATTER_ID__)
#   932  del __DW_BUILTINS__
#   933  del __DW_OUTPUT_FORMATTER_ID__
#   934  del __DW_IO__
#   935  del __DW_GET_SESSION_ID__
#   936  del __DW_OUTPUT_FORMATTER_CACHE__
#   937  del __DW_PANDAS_TRANSPORT__
#   938  del __DW_CONVERT_TO_PANDAS__
#   939  del __DW_OUTPUT_FORMATTER__
#   940  del __DW_OUTPUT_FORMATTER_API__
#   941  { echo $?; } 2>/dev/null
#   942  echo $SHELL       # Display the path of the current user's default shell
#   943  cat /etc/shells   # Show all available shells installed on the system
#   944  { echo $?; } 2>/dev/null
#   945  uname -a      # Display detailed system information (kernel, OS, architecture, hostname, etc.)
#   946  history       # Show the command history of the current shell session

# %% [markdown]
# ## 4. Help & Documentation
#
# - `man command`
# - `command --help`
# - `info command`
# - `whatis command`

# %% [markdown]
# ## 5. Listing & Viewing Files

# %%
ls        # List files and directories in the current directory
ls -l     # List files and directories in long format (permissions, owner, size, date)
ls -a     # List all files, including hidden files (those starting with .)
ls -la    # Long format listing including hidden files
# Out:
# 2
# Assignment01
# Assignment01.zip
# Assignment2
# Buffalo.csv
# CSCI381notes.docx
# DeliveryTime.csv
# Exercise-1.ipynb
# Exercise.ipynb
# ExerciseEdited.ipynb
# L02a.ipynb
# L03
# L03.ipynb
# L04.ipynb
# L05.ipynb
# L05a.ipynb
# L05b.ipynb
# L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# L06.ipynb
# L06.pdf
# L07 (1).ipynb
# L07-Exercises.ipynb
# L07.ipynb
# L08a.ipynb
# L08abrightspace.ipynb
# L08b.ipynb
# L09.ipynb
# L10.ipynb
# L11a.ipynb
# L11b.ipynb
# L1L2
# NOTES
# NOTESSS
# New York.csv
# Practice Quiz CSCI381.docx
# Programming Tools for the Data_otter_ai.txt
# San Francisco.csv
# Tutor Practice CSCI381.docx
# Washington DC.csv
# access (1).log
# access.log
# all.csv
# all_data.csv
# all_stocks_5yr.csv
# alldata.csv
# annotator.sh
# answers.txt
# attendance.txt
# bank.csv
# bigdf.csv
# booksdata.txt
# brandsData
# chat.txt
# churn.csv
# clean_logs.sh
# clean_logs.txt
# clients.csv
# count_message.sh
# countries.csv
# course.json
# crime.csv
# customers.csv
# cut.txt
# data
# data.json
# dataForCleaning.csv
# diabetes.csv
# ecom
# ecom (1).tar
# ecom.tar
# employees.txt
# error_logs.txt
# example.txt
# file1.txt
# files.txt
# labeled
# large_file.txt
# log.txt
# missingvaluesfile.csv
# mock_logs.txt
# mock_logs_practice.txt
# myscript.s
# names (1).txt
# names.txt
# newEcom
# newfile.txt
# news_links.txt
# no
# noheaderfile (1).csv
# noheaderfile.csv
# noindexfile.csv
# non_404_ips.txt
# normalized
# normalizer.sh
# nums.txt
# only_404_ips.txt
# otherpractice.ipynb
# output
# output.csv
# output.json
# owen_Workshop-02.ipynb
# owenhuang_WorkShop-1.ipynb
# p1.txt
# p2.txt
# practice.ipynb
# raw_data
# response1.json
# response2.json
# response3.json
# result.txt
# run.sh
# -rw-r--r--@   1 owenhuang  staff   33372160 Feb 19 15:45 ecom (1).tar
# -rw-r--r--@   1 owenhuang  staff   33372160 Jan 29 16:01 ecom.tar
# -rw-r--r--@   1 owenhuang  staff       2285 Feb 19 15:45 employees.txt
# -rw-r--r--    1 owenhuang  staff      18951 Feb 10 13:37 error_logs.txt
# -rw-r--r--    1 owenhuang  staff         12 Feb 10 21:29 example.txt
# -rw-r--r--    1 owenhuang  staff          0 Jan 27 14:29 file1.txt
# -rw-r--r--    1 owenhuang  staff        322 Jan 27 14:30 files.txt
# drwxr-xr-x    4 owenhuang  staff        128 Feb  1 10:49 labeled
# -rw-r--r--    1 owenhuang  staff  113888820 Feb 27 16:53 large_file.txt
# -rw-r--r--    1 owenhuang  staff         31 Feb 27 16:53 log.txt
# -rw-r--r--@   1 owenhuang  staff        299 Feb 19 16:00 missingvaluesfile.csv
# -rw-r--r--@   1 owenhuang  staff      53538 Jan 22 16:33 mock_logs.txt
# -rw-r--r--@   1 owenhuang  staff      54705 Feb  3 22:34 mock_logs_practice.txt
# -rwxr-xr-x@   1 owenhuang  staff        308 Jan 29 10:26 myscript.s
# -rw-r--r--@   1 owenhuang  staff        182 Jan 27 16:33 names (1).txt
# -rw-r--r--@   1 owenhuang  staff        182 Jan 27 16:33 names.txt
# drwxr-xr-x  546 owenhuang  staff      17472 Jan 30 02:26 newEcom
# -rw-r--r--@   1 owenhuang  staff         12 Jan 27 16:33 newfile.txt
# -rw-r--r--@   1 owenhuang  staff      12546 Mar  4 12:12 news_links.txt
# -rw-r--r--    1 owenhuang  staff          0 Jan 29 15:44 no
# -rw-r--r--@   1 owenhuang  staff         43 Feb 19 15:44 noheaderfile (1).csv
# -rw-r--r--@   1 owenhuang  staff         43 Feb 19 15:44 noheaderfile.csv
# -rw-r--r--@   1 owenhuang  staff     180805 Feb 19 15:44 noindexfile.csv
# -rw-r--r--    1 owenhuang  staff        275 Feb 10 16:10 non_404_ips.txt
# drwxr-xr-x    5 owenhuang  staff        160 Feb  1 10:50 normalized
# -rw-r--r--@   1 owenhuang  staff        258 Feb  3 12:26 normalizer.sh
# -rw-r--r--    1 owenhuang  staff          6 Jan 27 14:30 nums.txt
# -rw-r--r--    1 owenhuang  staff          0 Feb 10 16:10 only_404_ips.txt
# -rw-r--r--    1 owenhuang  staff       1467 Mar  3 20:39 otherpractice.ipynb
# -rw-r--r--    1 owenhuang  staff          0 Feb  1 10:50 output
# -rw-r--r--    1 owenhuang  staff         70 Mar  4 08:36 output.csv
# -rw-r--r--    1 owenhuang  staff        141 Mar  4 08:14 output.json
# -rw-r--r--@   1 owenhuang  staff      30335 Feb 27 19:26 owen_Workshop-02.ipynb
# -rw-r--r--@   1 owenhuang  staff      18720 Feb 27 16:47 owenhuang_WorkShop-1.ipynb
# -rw-r--r--    1 owenhuang  staff          6 Jan 27 14:30 p1.txt
# -rw-r--r--    1 owenhuang  staff          4 Jan 27 14:30 p2.txt
# -rw-r--r--    1 owenhuang  staff       2448 Feb 11 08:47 practice.ipynb
# drwxr-xr-x    5 owenhuang  staff        160 Feb  1 10:50 raw_data
# -rw-r--r--    1 owenhuang  staff       6460 Feb 10 15:57 response1.json
# -rw-r--r--    1 owenhuang  staff       5807 Feb 10 15:57 response2.json
# -rw-r--r--    1 owenhuang  staff       6713 Feb 10 15:57 response3.json
# -rw-r--r--@   1 owenhuang  staff          9 Jan 27 16:33 result.txt
# -rwxr-xr-x    1 owenhuang  staff         29 Jan 28 22:20 run.sh
# -rw-r--r--@   1 owenhuang  staff         18 Jan 27 16:33 sample (1).txt
# -rw-r--r--    1 owenhuang  staff         35 Mar  4 16:53 sample.txt
# -rw-r--r--    1 owenhuang  staff         18 Jan 29 12:35 sample2.txt
# -rw-r--r--    1 owenhuang  staff         18 Jan 29 12:49 sample3.txt
# -rw-r--r--@   1 owenhuang  staff       8192 Mar  4 16:53 school.db
# drwxr-xr-x@   3 owenhuang  staff         96 Jan 29 16:05 shared
# drwxr-xr-x@  12 owenhuang  staff        384 Jan 29 10:27 students
# -rw-r--r--@   1 owenhuang  staff        345 Feb 19 16:45 students (1).csv
# -rw-r--r--    1 owenhuang  staff         41 Mar  4 16:53 students.csv
# -rw-r--r--@   1 owenhuang  staff      24296 Feb 19 16:17 students_data.csv
# drwxr-xr-x    3 owenhuang  staff         96 Jan 25 21:46 testdir
# -rw-r--r--    1 owenhuang  staff        689 Feb 11 08:56 top_ip.sh
# -rw-r--r--    1 owenhuang  staff       1567 Feb  4 11:32 tutorpractice.ipynb
# -rw-r--r--    1 owenhuang  staff         10 Jan 27 15:24 uniq.txt
# -rw-r--r--@   1 owenhuang  staff        162 Feb  7 08:42 ~$CI381SHELL.docx
# .
# ..
# .DS_Store
# .git
# .gitignore
# .python-version
# 2
# Assignment01
# Assignment01.zip
# Assignment2
# Buffalo.csv
# CSCI381notes.docx
# DeliveryTime.csv
# Exercise-1.ipynb
# Exercise.ipynb
# ExerciseEdited.ipynb
# L02a.ipynb
# L03
# L03.ipynb
# L04.ipynb
# L05.ipynb
# L05a.ipynb
# L05b.ipynb
# L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# L06.ipynb
# L06.pdf
# L07 (1).ipynb
# L07-Exercises.ipynb
# L07.ipynb
# L08a.ipynb
# L08abrightspace.ipynb
# L08b.ipynb
# L09.ipynb
# L10.ipynb
# L11a.ipynb
# L11b.ipynb
# L1L2
# NOTES
# NOTESSS
# New York.csv
# Practice Quiz CSCI381.docx
# Programming Tools for the Data_otter_ai.txt
# San Francisco.csv
# Tutor Practice CSCI381.docx
# Washington DC.csv
# access (1).log
# access.log
# all.csv
# all_data.csv
# all_stocks_5yr.csv
# alldata.csv
# annotator.sh
# answers.txt
# attendance.txt
# bank.csv
# bigdf.csv
# booksdata.txt
# brandsData
# chat.txt
# churn.csv
# clean_logs.sh
# clean_logs.txt
# clients.csv
# count_message.sh
# countries.csv
# course.json
# crime.csv
# customers.csv
# cut.txt
# data
# data.json
# dataForCleaning.csv
# diabetes.csv
# ecom
# ecom (1).tar
# ecom.tar
# employees.txt
# error_logs.txt
# example.txt
# file1.txt
# files.txt
# labeled
# large_file.txt
# log.txt
# missingvaluesfile.csv
# mock_logs.txt
# mock_logs_practice.txt
# myscript.s
# names (1).txt
# names.txt
# newEcom
# newfile.txt
# news_links.txt
# no
# noheaderfile (1).csv
# noheaderfile.csv
# noindexfile.csv
# non_404_ips.txt
# normalized
# normalizer.sh
# nums.txt
# only_404_ips.txt
# otherpractice.ipynb
# output
# output.csv
# output.json
# owen_Workshop-02.ipynb
# owenhuang_WorkShop-1.ipynb
# p1.txt
# p2.txt
# practice.ipynb
# raw_data
# response1.json
# response2.json
# response3.json
# result.txt
# run.sh
# sample (1).txt
# sample.txt
# sample2.txt
# sample3.txt
# school.db
# shared
# students
# students (1).csv
# students.csv
# students_data.csv
# testdir
# top_ip.sh
# tutorpractice.ipynb
# uniq.txt
# ~$CI381SHELL.docx
# total 662376
# drwxr-xr-x@ 132 owenhuang  staff       4224 Mar  4 18:17 .
# drwxr-xr-x    7 owenhuang  staff        224 Mar  4 18:17 ..
# -rw-r--r--@   1 owenhuang  staff      12292 Feb 27 21:15 .DS_Store
# drwxr-xr-x   13 owenhuang  staff        416 Feb 27 21:32 .git
# -rw-r--r--    1 owenhuang  staff         25 Feb 24 21:16 .gitignore
# -rw-r--r--    1 owenhuang  staff         17 Feb 18 21:49 .python-version
# -rw-r--r--@   1 owenhuang  staff         12 Jan 27 16:33 2
# drwx------@  11 owenhuang  staff        352 Feb 24 16:30 Assignment01
# -rw-r--r--@   1 owenhuang  staff     273675 Jan 30 19:44 Assignment01.zip
# drwxr-xr-x    9 owenhuang  staff        288 Feb 24 15:34 Assignment2
# -rw-r--r--    1 owenhuang  staff       1355 Feb 27 19:08 Buffalo.csv
# -rw-r--r--@   1 owenhuang  staff    1170189 Feb 10 14:20 CSCI381notes.docx
# -rw-r--r--@   1 owenhuang  staff        808 Feb 19 15:45 DeliveryTime.csv
# -rw-r--r--@   1 owenhuang  staff     114791 Jan 27 14:45 Exercise-1.ipynb
# -rw-r--r--@   1 owenhuang  staff      21317 Feb 26 15:17 Exercise.ipynb
# -rw-r--r--@   1 owenhuang  staff      65906 Feb 26 15:32 ExerciseEdited.ipynb
# -rw-r--r--@   1 owenhuang  staff      97852 Mar  4 16:49 L02a.ipynb
# drwxr-xr-x    3 owenhuang  staff         96 Jan 28 10:14 L03
# -rw-r--r--@   1 owenhuang  staff      23226 Feb  7 11:31 L03.ipynb
# -rw-r--r--    1 owenhuang  staff        597 Feb  2 19:12 L04.ipynb
# -rw-r--r--@   1 owenhuang  staff     116662 Mar  4 16:54 L05.ipynb
# -rw-r--r--@   1 owenhuang  staff      17755 Feb 12 15:47 L05a.ipynb
# -rw-r--r--@   1 owenhuang  staff      11793 Feb 10 21:29 L05b.ipynb
# -rw-r--r--@   1 owenhuang  staff     126776 Feb 10 20:17 L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# -rw-r--r--@   1 owenhuang  staff     180805 Feb 19 15:44 noindexfile.csv
# -rw-r--r--    1 owenhuang  staff        275 Feb 10 16:10 non_404_ips.txt
# drwxr-xr-x    5 owenhuang  staff        160 Feb  1 10:50 normalized
# -rw-r--r--@   1 owenhuang  staff        258 Feb  3 12:26 normalizer.sh
# -rw-r--r--    1 owenhuang  staff          6 Jan 27 14:30 nums.txt
# -rw-r--r--    1 owenhuang  staff          0 Feb 10 16:10 only_404_ips.txt
# -rw-r--r--    1 owenhuang  staff       1467 Mar  3 20:39 otherpractice.ipynb
# -rw-r--r--    1 owenhuang  staff          0 Feb  1 10:50 output
# -rw-r--r--    1 owenhuang  staff         70 Mar  4 08:36 output.csv
# -rw-r--r--    1 owenhuang  staff        141 Mar  4 08:14 output.json
# -rw-r--r--@   1 owenhuang  staff      30335 Feb 27 19:26 owen_Workshop-02.ipynb
# -rw-r--r--@   1 owenhuang  staff      18720 Feb 27 16:47 owenhuang_WorkShop-1.ipynb
# -rw-r--r--    1 owenhuang  staff          6 Jan 27 14:30 p1.txt
# -rw-r--r--    1 owenhuang  staff          4 Jan 27 14:30 p2.txt
# -rw-r--r--    1 owenhuang  staff       2448 Feb 11 08:47 practice.ipynb
# drwxr-xr-x    5 owenhuang  staff        160 Feb  1 10:50 raw_data
# -rw-r--r--    1 owenhuang  staff       6460 Feb 10 15:57 response1.json
# -rw-r--r--    1 owenhuang  staff       5807 Feb 10 15:57 response2.json
# -rw-r--r--    1 owenhuang  staff       6713 Feb 10 15:57 response3.json
# -rw-r--r--@   1 owenhuang  staff          9 Jan 27 16:33 result.txt
# -rwxr-xr-x    1 owenhuang  staff         29 Jan 28 22:20 run.sh
# -rw-r--r--@   1 owenhuang  staff         18 Jan 27 16:33 sample (1).txt
# -rw-r--r--    1 owenhuang  staff         35 Mar  4 16:53 sample.txt
# -rw-r--r--    1 owenhuang  staff         18 Jan 29 12:35 sample2.txt
# -rw-r--r--    1 owenhuang  staff         18 Jan 29 12:49 sample3.txt
# -rw-r--r--@   1 owenhuang  staff       8192 Mar  4 16:53 school.db
# drwxr-xr-x@   3 owenhuang  staff         96 Jan 29 16:05 shared
# drwxr-xr-x@  12 owenhuang  staff        384 Jan 29 10:27 students
# -rw-r--r--@   1 owenhuang  staff        345 Feb 19 16:45 students (1).csv
# -rw-r--r--    1 owenhuang  staff         41 Mar  4 16:53 students.csv
# -rw-r--r--@   1 owenhuang  staff      24296 Feb 19 16:17 students_data.csv
# drwxr-xr-x    3 owenhuang  staff         96 Jan 25 21:46 testdir
# -rw-r--r--    1 owenhuang  staff        689 Feb 11 08:56 top_ip.sh
# -rw-r--r--    1 owenhuang  staff       1567 Feb  4 11:32 tutorpractice.ipynb
# -rw-r--r--    1 owenhuang  staff         10 Jan 27 15:24 uniq.txt
# -rw-r--r--@   1 owenhuang  staff        162 Feb  7 08:42 ~$CI381SHELL.docx

# %% [markdown]
# ### cat / less / head / tail / stat

# %%
echo -e "hi\nwelcome"
# Out:
# hi
# welcome

# %%
echo -e "a\nb\nc\nd" > sample.txt

# %%
cat sample.txt        # Display the entire contents of the file in the terminal
nl sample.txt         # Display the file contents with line numbers added
head -n 2 sample.txt  # Show only the first 2 lines of the file
tail -n 2 sample.txt  # Show only the last 2 lines of the file
tail -n +2 sample.txt # Show the file starting from line 2 to the end
stat sample.txt       # Display detailed file metadata (size, permissions, timestamps, inode)
# Out:
# a
# b
# c
# d
#      1	a
#      2	b
#      3	c
#      4	d
# a
# b
# c
# d
# b
# c
# d
# 16777233 228896325 -rw-r--r-- 1 owenhuang staff 0 8 "Mar  4 18:19:08 2026" "Mar  4 18:19:07 2026" "Mar  4 18:19:07 2026" "Jan 25 21:46:35 2026" 4096 8 0x40 sample.txt

# %% [markdown]
# ## 6. Creating Files & Directories

# %%
mkdir testdir                 # Create a new directory named testdir
mkdir -p testdir/sub1/sub2    # Create nested directories; no error if they already exist
touch file1.txt               # Create an empty file (or update timestamp if it exists)
# Out:
# mkdir: testdir: File exists

# %% [markdown]
# ## 7. Navigation

# %%
cd ..   # Move to the parent directory
cd ~    # Change to the current user's home directory
cd "/Users/owenhuang/Desktop/NYU/Spring 2026/CSCI381"
pwd
# Out:
# /Users/owenhuang/Desktop/NYU/Spring 2026/CSCI381

# %% [markdown]
# ## 8. Copying, Moving, Deleting

# %%
cp file1.txt file2.txt        # Copy file1.txt to a new file named file2.txt
cp -r testdir testdir_copy    # Recursively copy the directory testdir and its contents
mv file2.txt renamed.txt     # Rename (or move) file2.txt to renamed.txt
rm renamed.txt               # Delete the file renamed.txt
rm -r testdir_copy           # Recursively delete the directory testdir_copy and its contents

# %% [markdown]
# ## 9. Searching & Finding

# %%
find . -name "*.txt"   # Find all .txt files starting from the current directory
find . -type f         # Find all regular files starting from the current directory
find . -type d         # Find all directories starting from the current directory
# Out:
# ./files.txt
# ./uniq.txt
# ./news_links.txt
# ./mock_logs_practice.txt
# ./file1.txt
# ./NOTESSS/mock_logs.txt
# ./names.txt
# ./result.txt
# ./names (1).txt
# ./nums.txt
# ./attendance.txt
# ./large_file.txt
# ./normalized/scores_fold1.txt
# ./normalized/scores_fold3.txt
# ./normalized/scores_fold2.txt
# ./sample (1).txt
# ./employees.txt
# ./raw_data/scores_fold1.txt
# ./raw_data/scores_fold3.txt
# ./raw_data/scores_fold2.txt
# ./labeled/*.txt
# ./labeled/scores_fold1.txt
# ./mock_logs.txt
# ./booksdata.txt
# ./students/1002_Liam.txt
# ./students/1007_Sophia.txt
# ./students/1003_Emma.txt
# ./students/1004_Noah.txt
# ./students/1010_Lucas.txt
# ./students/1009_Isabella.txt
# ./students/1008_Elijah.txt
# ./students/1006_Oliver.txt
# ./students/1001_Olivia.txt
# ./students/1005_Ava.txt
# ./newfile.txt
# ./log.txt
# ./error_logs.txt
# ./Assignment2/totals.txt
# ./Assignment2/booksdata.txt
# ./Assignment2/sales-data/12.txt
# ./Assignment2/sales-data/10.txt
# ./Assignment2/sales-data/11.txt
# ./Assignment2/sales-data/9.txt
# ./Assignment2/sales-data/8.txt
# ./Assignment2/sales-data/5.txt
# ./Assignment2/sales-data/4.txt
# ./Assignment2/sales-data/6.txt
# ./Assignment2/sales-data/7.txt
# ./Assignment2/sales-data/3.txt
# ./Assignment2/sales-data/2.txt
# ./Assignment2/sales-data/1.txt
# ./Assignment2/bookstitles.txt
# ./chat.txt
# ./answers.txt
# ./example.txt
# ./L1L2/file2.txt
# ./L1L2/file1.txt
# ./L1L2/mock_logs.txt
# ./p2.txt
# ./non_404_ips.txt
# ./Programming Tools for the Data_otter_ai.txt
# ./p1.txt
# ./data/file1.txt
# ./only_404_ips.txt
# ./cut.txt
# ./clean_logs.txt
# ./sample2.txt
# ./sample.txt
# ./sample3.txt
# ./files.txt
# ./missingvaluesfile.csv
# ./uniq.txt
# ./news_links.txt
# ./students (1).csv
# ./mock_logs_practice.txt
# ./customers.csv
# ./file1.txt
# ./NOTESSS/Shell and Command-Line Operations.pdf
# ./NOTESSS/matplotlib_tutorial.ipynb
# ./NOTESSS/L11b.pdf
# ./NOTESSS/N02 (1).pdf
# ./NOTESSS/L11a.pdf
# ./NOTESSS/L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# ./NOTESSS/L05 (1).pdf
# ./NOTESSS/Exercise-1.pdf
# ./NOTESSS/L08a.ipynb
# ./NOTESSS/L09.ipynb
# ./NOTESSS/L10.ipynb
# ./NOTESSS/L08-Functional Python Tools (1).pdf
# ./NOTESSS/L08-Functional Python Tools.pdf
# ./NOTESSS/N03 (1).pdf
# ./NOTESSS/N03.pdf
# ./NOTESSS/L06 (1).pdf
# ./NOTESSS/N02.pdf
# ./NOTESSS/L00.pdf
# ./NOTESSS/L02.pdf
# ./NOTESSS/L05-Python Data Structure Selection.pdf
# ./NOTESSS/L09-A Guide to Pandas.pdf
# ./NOTESSS/Exercise.ipynb
# ./NOTESSS/N01 (1).pdf
# ./NOTESSS/N01.pdf
# ./NOTESSS/L03.pdf
# ./NOTESSS/L07.pdf
# ./NOTESSS/L06.pdf
# ./NOTESSS/L10.pdf
# ./NOTESSS/mock_logs.txt
# ./NOTESSS/L05.pdf
# ./NOTESSS/L10-Data Grouping and Dataset Merging.pdf
# ./NOTESSS/L09.pdf
# ./NOTESSS/L06.ipynb
# ./NOTESSS/seaborn_mastery.ipynb
# ./NOTESSS/L10-Data Grouping and Dataset Merging (1).pdf
# ./NOTESSS/Shell and Command-Line Operations (1).pdf
# ./NOTESSS/L07-Python Control Flow.pdf
# ./NOTESSS/L02.ipynb
# ./NOTESSS/CS-381_Midterm_Review.pdf
# ./NOTESSS/L11b (1).pdf
# ./NOTESSS/01-An Introduction to Data Roles.pdf
# ./NOTESSS/Students Note-01.docx (1).pdf
# ./NOTESSS/L07.ipynb
# ./NOTESSS/L07-Python Control Flow (1).pdf
# ./NOTESSS/Data Scientist Visualization Decision Table.pdf
# ./NOTESSS/L05.ipynb
# ./NOTESSS/L07-Exercises.ipynb
# ./NOTESSS/Code.zip
# ./NOTESSS/L00 (1).pdf
# ./NOTESSS/ols_die_problem.ipynb
# ./NOTESSS/01-An Introduction to Data Roles (1).pdf
# ./NOTESSS/L08a.pdf
# ./NOTESSS/L09 (1).pdf
# ./NOTESSS/students.csv
# ./NOTESSS/Students Note-01.docx.pdf
# ./NOTESSS/L03.ipynb
# ./dataForCleaning.csv
# ./bank.csv
# ./Practice Quiz CSCI381.docx
# ./noheaderfile.csv
# ./names.txt
# ./L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# ./San Francisco.csv
# ./L08a.ipynb
# ./L09.ipynb
# ./.DS_Store
# ./crime.csv
# ./result.txt
# ./names (1).txt
# ./nums.txt
# ./clients.csv
# ./countries.csv
# ./attendance.txt
# ./top_ip.sh
# ./L10.ipynb
# ./newEcom/apple/construction.csv
# ./newEcom/apple/electronics.csv
# ./newEcom/apple/computers.csv
# ./newEcom/blehk/furniture.csv
# ./newEcom/coolinar/furniture.csv
# ./newEcom/sencor/furniture.csv
# ./newEcom/sencor/computers.csv
# ./newEcom/sencor/appliances.csv
# ./newEcom/altex/electronics.csv
# ./newEcom/borner/appliances.csv
# ./newEcom/lenovo/electronics.csv
# ./newEcom/lenovo/computers.csv
# ./newEcom/iiyama/computers.csv
# ./newEcom/cliny/apparel.csv
# ./newEcom/honor/electronics.csv
# ./newEcom/filtero/appliances.csv
# ./newEcom/kerasys/furniture.csv
# ./newEcom/kerasys/appliances.csv
# ./newEcom/awax/electronics.csv
# ./newEcom/olympus/electronics.csv
# ./newEcom/yoobao/computers.csv
# ./newEcom/logitech/electronics.csv
# ./newEcom/logitech/computers.csv
# ./newEcom/lemark/construction.csv
# ./newEcom/asics/accessories.csv
# ./newEcom/akitio/computers.csv
# ./newEcom/xgimi/electronics.csv
# ./newEcom/intel/computers.csv
# ./newEcom/sandisk/computers.csv
# ./newEcom/isolon/furniture.csv
# ./newEcom/seasonic/computers.csv
# ./newEcom/xp-pen/electronics.csv
# ./newEcom/rapoo/computers.csv
# ./newEcom/rivacase/accessories.csv
# ./newEcom/rivacase/computers.csv
# ./newEcom/simba/furniture.csv
# ./newEcom/synology/apparel.csv
# ./newEcom/ubiquiti/computers.csv
# ./newEcom/brother/computers.csv
# ./newEcom/brother/appliances.csv
# ./newEcom/thermex/appliances.csv
# ./newEcom/deluxe/electronics.csv
# ./newEcom/deluxe/computers.csv
# ./newEcom/deluxe/stationery.csv
# ./newEcom/pyrex/furniture.csv
# ./newEcom/cilek/furniture.csv
# ./newEcom/milan/electronics.csv
# ./newEcom/pccooler/computers.csv
# ./newEcom/sennheiser/electronics.csv
# ./newEcom/technogym/electronics.csv
# ./newEcom/technogym/sport.csv
# ./newEcom/elfe/apparel.csv
# ./newEcom/zeta/furniture.csv
# ./newEcom/agu/electronics.csv
# ./newEcom/hansa/furniture.csv
# ./newEcom/hansa/appliances.csv
# ./newEcom/domini/furniture.csv
# ./newEcom/topeak/construction.csv
# ./newEcom/topeak/accessories.csv
# ./newEcom/baboo/kids.csv
# ./newEcom/micro/kids.csv
# ./newEcom/kitchenaid/computers.csv
# ./newEcom/kitchenaid/appliances.csv
# ./newEcom/kaabo/kids.csv
# ./newEcom/prestigio/construction.csv
# ./newEcom/prestigio/electronics.csv
# ./newEcom/prestigio/computers.csv
# ./newEcom/prestigio/auto.csv
# ./newEcom/curver/furniture.csv
# ./newEcom/crucial/computers.csv
# ./newEcom/ezviz/furniture.csv
# ./newEcom/wxd/accessories.csv
# ./newEcom/rinnai/construction.csv
# ./newEcom/panasonic/furniture.csv
# ./newEcom/panasonic/electronics.csv
# ./newEcom/panasonic/medicine.csv
# ./newEcom/panasonic/appliances.csv
# ./newEcom/milight/furniture.csv
# ./newEcom/awei/electronics.csv
# ./newEcom/gopro/electronics.csv
# ./newEcom/cinemood/electronics.csv
# ./newEcom/cougar/furniture.csv
# ./newEcom/cougar/computers.csv
# ./newEcom/casio/electronics.csv
# ./newEcom/grans/furniture.csv
# ./newEcom/lion/computers.csv
# ./newEcom/gtec/construction.csv
# ./newEcom/biolane/computers.csv
# ./newEcom/genius/electronics.csv
# ./newEcom/genius/computers.csv
# ./newEcom/powerplant/computers.csv
# ./newEcom/zenit/electronics.csv
# ./newEcom/phantom/electronics.csv
# ./newEcom/sony/electronics.csv
# ./newEcom/sony/computers.csv
# ./newEcom/sony/apparel.csv
# ./newEcom/sony/sport.csv
# ./newEcom/atlant/appliances.csv
# ./newEcom/ecologystone/construction.csv
# ./newEcom/goodyear/auto.csv
# ./newEcom/anymode/computers.csv
# ./newEcom/mattel/furniture.csv
# ./newEcom/mattel/kids.csv
# ./newEcom/gerat/furniture.csv
# ./newEcom/gerat/appliances.csv
# ./newEcom/okko/electronics.csv
# ./newEcom/vivo/electronics.csv
# ./newEcom/tefal/furniture.csv
# ./newEcom/tefal/appliances.csv
# ./newEcom/dougez/kids.csv
# ./newEcom/mio/auto.csv
# ./newEcom/epson/electronics.csv
# ./newEcom/epson/computers.csv
# ./newEcom/epson/stationery.csv
# ./newEcom/braun/medicine.csv
# ./newEcom/braun/appliances.csv
# ./newEcom/grohe/construction.csv
# ./newEcom/grohe/furniture.csv
# ./newEcom/sanc/computers.csv
# ./newEcom/superlux/appliances.csv
# ./Tutor Practice CSCI381.docx
# ./no
# ./alldata.csv
# ./response3.json
# ./Exercise-1.ipynb
# ./large_file.txt
# ./course.json
# ./normalized/scores_fold1.txt
# ./normalized/scores_fold3.txt
# ./normalized/scores_fold2.txt
# ./sample (1).txt
# ./Exercise.ipynb
# ./output.json
# ./normalizer.sh
# ./employees.txt
# ./output
# ./L03/L03.pdf
# ./Buffalo.csv
# ./L08b.ipynb
# ./L06.pdf
# ./all_data.csv
# ./shared/datafiles/.DS_Store
# ./raw_data/scores_fold1.txt
# ./raw_data/scores_fold3.txt
# ./raw_data/scores_fold2.txt
# ./L02a.ipynb
# ./noheaderfile (1).csv
# ./labeled/*.txt
# ./labeled/scores_fold1.txt
# ./output.csv
# ./mock_logs.txt
# ./response2.json
# ./~$CI381SHELL.docx
# ./brandsData/galaxy.csv
# ./brandsData/cdc.csv
# ./brandsData/muljhtidom.csv
# ./brandsData/glassware.csv
# ./brandsData/alienware.csv
# ./brandsData/garanterm.csv
# ./brandsData/franke.csv
# ./brandsData/ship.csv
# ./brandsData/aoki.csv
# ./brandsData/tsg.csv
# ./brandsData/x-cooler.csv
# ./brandsData/atmor.csv
# ./brandsData/crucial.csv
# ./brandsData/kyocera.csv
# ./brandsData/bradex.csv
# ./brandsData/aerocool.csv
# ./brandsData/powerplant.csv
# ./brandsData/camelion.csv
# ./brandsData/seasonic.csv
# ./brandsData/inhouse.csv
# ./brandsData/kurzweil.csv
# ./brandsData/ruggear.csv
# ./brandsData/qmax.csv
# ./brandsData/blehk.csv
# ./brandsData/babyliss.csv
# ./brandsData/dougez.csv
# ./brandsData/fly.csv
# ./brandsData/aeg.csv
# ./brandsData/ariston.csv
# ./brandsData/everlast.csv
# ./brandsData/casio.csv
# ./brandsData/lefard.csv
# ./brandsData/whirlpool.csv
# ./brandsData/curver.csv
# ./brandsData/deluxe.csv
# ./brandsData/thermaltake.csv
# ./brandsData/kaspersky.csv
# ./brandsData/hms.csv
# ./brandsData/eset.csv
# ./brandsData/epson.csv
# ./brandsData/lg.csv
# ./brandsData/avrora.csv
# ./brandsData/vikhrjh.csv
# ./brandsData/runwin.csv
# ./brandsData/oral-b.csv
# ./brandsData/harper.csv
# ./brandsData/dewalt.csv
# ./brandsData/krups.csv
# ./brandsData/jose.csv
# ./brandsData/continent.csv
# ./brandsData/stiga.csv
# ./brandsData/beurer.csv
# ./tutorpractice.ipynb
# ./response1.json
# ./newfile.txt
# ./L04.ipynb
# ./log.txt
# ./L06.ipynb
# ./practice.ipynb
# ./NOTES/L05-Python Data Structure Selection (1).pdf
# ./NOTES/N02 (1).pdf
# ./NOTES/L06-The Data Journey_ From Remote Servers to Python Containers.pdf
# ./NOTES/L05 (1).pdf
# ./NOTES/Exercise-1.pdf
# ./NOTES/.DS_Store
# ./NOTES/L08-Functional Python Tools.pdf
# ./NOTES/N03 (1).pdf
# ./NOTES/L06 (1).pdf
# ./NOTES/L00.pdf
# ./NOTES/L02.pdf
# ./NOTES/N01.pdf
# ./NOTES/L03.pdf
# ./NOTES/L07.pdf
# ./NOTES/Code/normalizer.sh
# ./NOTES/Code/dailyPreprocessing.sh
# ./NOTES/Code/annotator.sh
# ./NOTES/L06.ipynb
# ./NOTES/Shell and Command-Line Operations (1).pdf
# ./NOTES/L07-Python Control Flow.pdf
# ./NOTES/L02.ipynb
# ./NOTES/Students Note-01.docx (1).pdf
# ./NOTES/L05.ipynb
# ./NOTES/Code.zip
# ./NOTES/01-An Introduction to Data Roles (1).pdf
# ./NOTES/L08a.pdf
# ./NOTES/L03.ipynb
# ./ecom.tar
# ./all.csv
# ./clean_logs.sh
# ./.gitignore
# ./error_logs.txt
# ./Assignment2/.DS_Store
# ./Assignment2/totals.txt
# ./Assignment2/OwenHuangAssignment02.ipynb
# ./Assignment2/booksdata.txt
# ./Assignment2/sales-data.zip
# ./Assignment2/sales-data/12.txt
# ./Assignment2/sales-data/10.txt
# ./Assignment2/sales-data/11.txt
# ./Assignment2/sales-data/9.txt
# ./Assignment2/sales-data/8.txt
# ./Assignment2/sales-data/5.txt
# ./Assignment2/sales-data/4.txt
# ./Assignment2/sales-data/6.txt
# ./Assignment2/sales-data/7.txt
# ./Assignment2/sales-data/3.txt
# ./Assignment2/sales-data/2.txt
# ./Assignment2/sales-data/1.txt
# ./Assignment2/bookstitles.txt
# ./Assignment01/One year.csv
# ./Assignment01/.DS_Store
# ./Assignment01/OwenHuangAssignment01.ipynb
# ./Assignment01/Month-to-month.csv
# ./Assignment01/data_v2.csv
# ./Assignment01/Two year.csv
# ./Assignment01/data.csv
# ./Assignment01/data_v3.csv
# ./Assignment01/.ipynb_checkpoints/Assignment01-checkpoint.ipynb
# ./L11b.ipynb
# ./chat.txt
# ./noindexfile.csv
# ./.python-version
# ./answers.txt
# ./example.txt
# ./school.db
# ./L05a.ipynb
# ./New York.csv
# ./DeliveryTime.csv
# ./L1L2/file2.txt
# ./L1L2/file1.txt
# ./L1L2/Exercise-1.pdf
# ./L1L2/L00.pdf
# ./L1L2/L02.pdf
# ./L1L2/mock_logs.txt
# ./L1L2/01-An Introduction to Data Roles.pdf
# ./L1L2/Students Note-01.docx.pdf
# ./L07.ipynb
# ./L07 (1).ipynb
# ./p2.txt
# ./access.log
# ./diabetes.csv
# ./non_404_ips.txt
# ./ExerciseEdited.ipynb
# ./ecom (1).tar
# ./students_data.csv
# ./Programming Tools for the Data_otter_ai.txt
# ./.git/config
# ./.git/objects/6f/f8d3ae6221b57d71fa7a36577b44598f4f9030
# ./.git/objects/03/cc66280f658f6ea5be64ff919fe5b1f6471506
# ./.git/objects/6a/3dae34ed74409b81fd457e1bc8b54d0420f850
# ./.git/objects/5f/86b07612517669e65da6f9955a9823671b5ef5
# ./.git/objects/05/e0c7f88029a5eebdc5391a2214db2de675eb37
# ./.git/objects/b5/726f763c8271faf319cf65574a74a876174b80
# ./.git/objects/d9/e4d8f2bf0f6b969ded9ca5473a3363d90e3a00
# ./.git/objects/d9/a76c8cd1fd289b91995c39dfdeeef00e30a786
# ./.git/objects/d7/87cf0cc6811811775e5d4d91d370cd912bec83
# ./.git/objects/ab/834192fa4df3594028d87c1e1fdada331dfd67
# ./.git/objects/ec/b3e0f55e8377e4ae806057a01107692ea38766
# ./.git/objects/20/853d935697c0a17128decbf3e51078cd287d87
# ./.git/objects/20/cdd52e23a38521a30ed3911124e4ad5210c16f
# ./.git/objects/4b/35c587e4d4f22a3b47c0eb41c04a6111143609
# ./.git/objects/pack/pack-2c7ce2d957c947ab713c65fa1ce043da7eff3803.rev
# ./.git/objects/pack/pack-2c7ce2d957c947ab713c65fa1ce043da7eff3803.pack
# ./.git/objects/pack/pack-2c7ce2d957c947ab713c65fa1ce043da7eff3803.idx
# ./.git/objects/11/d89a8b4268d2dad169dbe30c7fd5fcd455e6e7
# ./.git/objects/1f/8a93500f23c440c489b6a3b59b2cd230e8da44
# ./.git/objects/8a/a69bd78d2b32113df217a07069ddcd82cb75da
# ./.git/objects/26/3eba1d21854d4269eb2dec13eb8a85d56b90b7
# ./.git/objects/81/d53d1c5bfca79657369406ba7f0aff9facc3a9
# ./.git/objects/81/5469347a5896baceddbf0da5fb87190d7ee0ad
# ./.git/objects/72/b4fffe0a19b2cd28cfe3219748175d391f47a6
# ./.git/objects/43/25512aa15691c2f4700e2702fa2cb8e6cdbf59
# ./.git/objects/38/c669e16aabf878496d424bd3fa12f4df55aba6
# ./.git/objects/info/commit-graph
# ./.git/objects/info/packs
# ./.git/objects/54/a68701e1420f1a1163634259f0e081eae522e6
# ./.git/objects/37/cec9d01a9a6c2ad82e2e9fcf38bd23345f6e2d
# ./.git/objects/0a/44e2e3ebd7208a5e3aa7564a64a77ebe9ea472
# ./.git/objects/ff/0da2686b7fe3afb6ab776be68abbdb2209b939
# ./.git/objects/f1/0030272c7b8e908577756ac56f090e56b88e2a
# ./.git/objects/e0/5278b21bcf8995edbccc841fca9bf4d68f8317
# ./.git/objects/82/a859b3bf17a7e0f963afa0e8c481f61dd54384
# ./.git/objects/2b/95fceb76f5cf6e55d18894d5f51c491d6fb78e
# ./.git/objects/8b/eb6e680768d38901bc39dc19d18db46cee5d8a
# ./.git/objects/7a/76f3a422413c85737f1b88df6dd0f357c43ea5
# ./.git/HEAD
# ./.git/info/exclude
# ./.git/info/refs
# ./.git/logs/HEAD
# ./.git/logs/refs/heads/main
# ./.git/logs/refs/remotes/origin/main
# ./.git/description
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/sendemail-validate.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/pre-merge-commit.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/update.sample
# ./.git/hooks/push-to-checkout.sample
# ./.git/refs/heads/main
# ./.git/refs/remotes/origin/main
# ./.git/gk/config
# ./.git/index
# ./.git/COMMIT_EDITMSG
# ./CSCI381notes.docx
# ./p1.txt
# ./L05.ipynb
# ./ecom/computers/deepcool.csv
# ./ecom/computers/gembird.csv
# ./ecom/computers/huntkey.csv
# ./ecom/computers/svc.csv
# ./ecom/computers/google.csv
# ./ecom/computers/kingston.csv
# ./ecom/computers/prestigio.csv
# ./ecom/computers/none.csv
# ./ecom/computers/xerox.csv
# ./ecom/computers/polaroid.csv
# ./ecom/computers/asus.csv
# ./ecom/computers/bloody.csv
# ./ecom/computers/corsair.csv
# ./ecom/computers/ergolux.csv
# ./ecom/computers/msi.csv
# ./ecom/computers/kitchenaid.csv
# ./ecom/computers/jetpik.csv
# ./ecom/computers/roevuta.csv
# ./ecom/computers/rapoo.csv
# ./ecom/computers/pocketbook.csv
# ./ecom/computers/ehra.csv
# ./ecom/computers/defender.csv
# ./ecom/computers/sanc.csv
# ./ecom/computers/genius.csv
# ./ecom/computers/thule.csv
# ./ecom/computers/lenovo.csv
# ./ecom/computers/sony.csv
# ./ecom/computers/kenwood.csv
# ./ecom/computers/president.csv
# ./ecom/computers/amazon.csv
# ./ecom/computers/sencor.csv
# ./ecom/computers/noctua.csv
# ./ecom/computers/akitio.csv
# ...
# ./ecom/furniture/ezviz.csv
# ./ecom/furniture/mattel.csv
# ./ecom/furniture/maestro.csv
# ./ecom/furniture/kerasys.csv
# ./ecom/furniture/airline.csv
# ./ecom/furniture/bosch.csv
# ./ecom/furniture/tramp.csv
# ./ecom/furniture/simba.csv
# ./ecom/furniture/hansa.csv
# ./ecom/furniture/xiaomi.csv
# ./ecom/furniture/motorola.csv
# ./ecom/furniture/weber.csv
# ./ecom/furniture/acana.csv
# ./ecom/furniture/dxracer.csv
# ./ecom/furniture/samsung.csv
# ./ecom/furniture/vitehks.csv
# ./ecom/furniture/philips.csv
# ./ecom/furniture/panasonic.csv
# ./ecom/furniture/cougar.csv
# ./ecom/furniture/peterhof.csv
# ./ecom/furniture/belita.csv
# ./ecom/furniture/vitek.csv
# ./ecom/furniture/alinco.csv
# ./ecom/furniture/gorenje.csv
# ./ecom/furniture/biol.csv
# ./ecom/furniture/victoria.csv
# ./ecom/furniture/biomio.csv
# ./ecom/furniture/dogland.csv
# ./ecom/furniture/grans.csv
# ./ecom/furniture/gamdias.csv
# ./ecom/furniture/resto.csv
# ./ecom/furniture/polaris.csv
# ./ecom/furniture/lamart.csv
# ./ecom/furniture/orion.csv
# ./ecom/furniture/belcando.csv
# ./ecom/furniture/x-game.csv
# ./ecom/furniture/wilmax.csv
# ./ecom/furniture/cars.csv
# ./ecom/furniture/milight.csv
# ./ecom/furniture/different.csv
# ./ecom/furniture/muljhtidom.csv
# ./ecom/furniture/glassware.csv
# ./ecom/furniture/aerocool.csv
# ./ecom/furniture/inhouse.csv
# ./ecom/furniture/blehk.csv
# ./ecom/furniture/curver.csv
# ./ecom/furniture/thermaltake.csv
# ./ecom/furniture/lg.csv
# ./ecom/furniture/avrora.csv
# ./ecom/furniture/oral-b.csv
# ./ecom/furniture/stiga.csv
# ./ecom/.csv
# ./ecom/medicine/omron.csv
# ./ecom/medicine/medisana.csv
# ./ecom/medicine/braun.csv
# ./ecom/medicine/rowenta.csv
# ./ecom/medicine/philips.csv
# ./ecom/medicine/panasonic.csv
# ./ecom/construction/svc.csv
# ./ecom/construction/makita.csv
# ./ecom/construction/prestigio.csv
# ./ecom/construction/eglo.csv
# ./ecom/construction/none.csv
# ./ecom/construction/sbs.csv
# ./ecom/construction/usams.csv
# ./ecom/construction/neptun.csv
# ./ecom/construction/navien.csv
# ./ecom/construction/wurth.csv
# ./ecom/construction/huter.csv
# ./ecom/construction/moshi.csv
# ./ecom/construction/rinnai.csv
# ./ecom/construction/apple.csv
# ./ecom/construction/topeak.csv
# ./ecom/construction/lotte.csv
# ./ecom/construction/grohe.csv
# ./ecom/construction/hintek.csv
# ./ecom/construction/eurolux.csv
# ./ecom/construction/satechi.csv
# ./ecom/construction/huawei.csv
# ./ecom/construction/ava.csv
# ./ecom/construction/neo.csv
# ./ecom/construction/bosch.csv
# ./ecom/construction/samsung.csv
# ./ecom/construction/gtec.csv
# ./ecom/construction/resanta.csv
# ./ecom/construction/karcher.csv
# ./ecom/construction/orico.csv
# ./ecom/construction/energea.csv
# ./ecom/construction/ecologystone.csv
# ./ecom/construction/decoroom.csv
# ./ecom/construction/inkax.csv
# ./ecom/construction/metabo.csv
# ./ecom/construction/lemark.csv
# ./ecom/construction/tece.csv
# ./ecom/construction/stihl.csv
# ./ecom/construction/hyperx.csv
# ./ecom/construction/franke.csv
# ./ecom/construction/ariston.csv
# ./ecom/construction/vikhrjh.csv
# ./ecom/construction/harper.csv
# ./ecom/construction/dewalt.csv
# ./ecom/apparel/sibrtekh.csv
# ./ecom/apparel/citoderm.csv
# ./ecom/apparel/elfe.csv
# ./ecom/apparel/chicco.csv
# ./ecom/apparel/ggg.csv
# ./ecom/apparel/sony.csv
# ./ecom/apparel/synology.csv
# ./ecom/apparel/cliny.csv
# ./ecom/apparel/xbox.csv
# ./ecom/apparel/chistotel.csv
# ./ecom/apparel/qnap.csv
# ./ecom/apparel/aquael.csv
# ./ecom/apparel/nintendo.csv
# ./ecom/apparel/rossija.csv
# ./ecom/apparel/savic.csv
# ./ecom/apparel/dji.csv
# ./ecom/apparel/mujjo.csv
# ./ecom/apparel/palisad.csv
# ./ecom/apparel/transcend.csv
# ./ecom/apparel/nvidia.csv
# ./ecom/apparel/everlast.csv
# ./ecom/kids/deepcool.csv
# ./ecom/kids/gembird.csv
# ./ecom/kids/fissman.csv
# ./ecom/kids/none.csv
# ./ecom/kids/asus.csv
# ./ecom/kids/corsair.csv
# ./ecom/kids/chicco.csv
# ./ecom/kids/highwaybaby.csv
# ./ecom/kids/nuk.csv
# ./ecom/kids/alpengaudi.csv
# ./ecom/kids/rastar.csv
# ./ecom/kids/nzxt.csv
# ./ecom/kids/avermedia.csv
# ./ecom/kids/kaabo.csv
# ./ecom/kids/micro.csv
# ./ecom/kids/footwork.csv
# ./ecom/kids/baboo.csv
# ./ecom/kids/jonsbo.csv
# ./ecom/kids/cablexpert.csv
# ./ecom/kids/barbie.csv
# ./ecom/kids/ninebot.csv
# ./ecom/kids/globber.csv
# ./ecom/kids/goliath.csv
# ./ecom/kids/dc-girls.csv
# ./ecom/kids/neo.csv
# ./ecom/kids/mattel.csv
# ./ecom/kids/id-cooling.csv
# ./ecom/kids/alis.csv
# ./ecom/kids/joonies.csv
# ./ecom/kids/tribe.csv
# ./ecom/kids/xiaomi.csv
# ./ecom/kids/gamemax.csv
# ./ecom/kids/joerex.csv
# ./ecom/kids/transcend.csv
# ./ecom/kids/lol.csv
# ./ecom/kids/orico.csv
# ./ecom/kids/eastcoast.csv
# ./ecom/kids/xigmatek.csv
# ./ecom/kids/cdc.csv
# ./ecom/kids/x-cooler.csv
# ./ecom/kids/aerocool.csv
# ./ecom/kids/dougez.csv
# ./ecom/kids/lefard.csv
# ./ecom/kids/thermaltake.csv
# ./ecom/kids/jose.csv
# ./ecom/kids/stiga.csv
# ./ecom/country_yard/makita.csv
# ./ecom/country_yard/huter.csv
# ./ecom/country_yard/alex.csv
# ./ecom/country_yard/eurolux.csv
# ./ecom/country_yard/bosch.csv
# ./ecom/country_yard/casada.csv
# ./ecom/country_yard/karcher.csv
# ./ecom/country_yard/beurer.csv
# ./Assignment01.zip
# ./L07-Exercises.ipynb
# ./data/file1.txt
# ./access (1).log
# ./only_404_ips.txt
# ./L11a.ipynb
# ./count_message.sh
# ./all_stocks_5yr.csv
# ./L08abrightspace.ipynb
# ./cut.txt
# ./myscript.s
# ./clean_logs.txt
# ./otherpractice.ipynb
# ./owen_Workshop-02.ipynb
# ./sample2.txt
# ./L05b.ipynb
# ./bigdf.csv
# ./Washington DC.csv
# ./2
# ./sample.txt
# ./students.csv
# ./churn.csv
# ./annotator.sh
# ./owenhuang_WorkShop-1.ipynb
# ./sample3.txt
# ./L03.ipynb
# .
# ./NOTESSS
# ./newEcom
# ./newEcom/apple
# ./newEcom/blehk
# ./newEcom/coolinar
# ./newEcom/sencor
# ./newEcom/altex
# ./newEcom/borner
# ./newEcom/lenovo
# ./newEcom/iiyama
# ./newEcom/cliny
# ./newEcom/honor
# ./newEcom/filtero
# ./newEcom/kerasys
# ./newEcom/awax
# ./newEcom/olympus
# ./newEcom/yoobao
# ./newEcom/logitech
# ./newEcom/lemark
# ./newEcom/asics
# ./newEcom/akitio
# ./newEcom/xgimi
# ./newEcom/intel
# ./newEcom/sandisk
# ./newEcom/isolon
# ./newEcom/seasonic
# ./newEcom/xp-pen
# ./newEcom/rapoo
# ./newEcom/rivacase
# ./newEcom/simba
# ./newEcom/synology
# ./newEcom/ubiquiti
# ./newEcom/brother
# ./newEcom/thermex
# ./newEcom/deluxe
# ./newEcom/pyrex
# ./newEcom/cilek
# ./newEcom/milan
# ./newEcom/pccooler
# ./newEcom/sennheiser
# ./newEcom/technogym
# ./newEcom/elfe
# ./newEcom/zeta
# ./newEcom/agu
# ./newEcom/hansa
# ./newEcom/domini
# ./newEcom/topeak
# ./newEcom/baboo
# ./newEcom/micro
# ./newEcom/alex
# ./newEcom/ergolux
# ./newEcom/weber
# ./newEcom/beurer
# ./newEcom/legrand
# ./newEcom/topperr
# ./newEcom/babyliss
# ./newEcom/alis
# ./newEcom/demidovskiy
# ./newEcom/gutrend
# ./newEcom/inkax
# ./newEcom/optoma
# ./newEcom/energea
# ./newEcom/ritmix
# ./newEcom/wilson
# ./newEcom/harper
# ./newEcom/different
# ./newEcom/wonlex
# ./newEcom/aerocool
# ./newEcom/cdc
# ./newEcom/saramonic
# ./newEcom/starline
# ./newEcom/gorenje
# ./newEcom/plantronics
# ./newEcom/everlast
# ./newEcom/altel
# ./newEcom/axper
# ./newEcom/microlab
# ./newEcom/thomas
# ./newEcom/lori
# ./newEcom/philips
# ./newEcom/proscreen
# ./newEcom/arktika
# ./newEcom/incase
# ./newEcom/noctua
# ./newEcom/citoderm
# ./newEcom/jetair
# ./newEcom/pozis
# ./newEcom/maxwell
# ./newEcom/tamron
# ./newEcom/tp-link
# ./newEcom/franke
# ./newEcom/genau
# ./newEcom/none
# ./newEcom/zowie
# ./newEcom/pocketbook
# ./newEcom/pedigree
# ./newEcom/jbl
# ./newEcom/shenzhen
# ./newEcom/aimoto
# ./newEcom/kaspersky
# ./newEcom/mart
# ./newEcom/midea
# ./newEcom/singer
# ./newEcom/eset
# ./newEcom/vipe
# ./newEcom/aeg
# ./newEcom/gemon
# ./newEcom/dabur
# ./newEcom/provence
# ./newEcom/arnica
# ./newEcom/audac
# ./newEcom/vitabiotics
# ./newEcom/airline
# ./newEcom/x-game
# ./newEcom/colorfix
# ./newEcom/usams
# ./newEcom/bose
# ./newEcom/hitachi
# ./newEcom/deepcool
# ./newEcom/matrix
# ./newEcom/asrock
# ./newEcom/bequiet
# ./newEcom/cullmann
# ./newEcom/defender
# ./newEcom/global
# ./newEcom/fujifilm
# ./newEcom/camelion
# ./newEcom/riva
# ./newEcom/lihom
# ./newEcom/rowenta
# ./newEcom/kitchenaid
# ./newEcom/kaabo
# ./newEcom/prestigio
# ./newEcom/curver
# ./newEcom/crucial
# ./newEcom/ezviz
# ./newEcom/wxd
# ./newEcom/rinnai
# ./newEcom/panasonic
# ./newEcom/milight
# ./newEcom/awei
# ./newEcom/gopro
# ./newEcom/cinemood
# ./newEcom/cougar
# ./newEcom/casio
# ./newEcom/grans
# ./newEcom/lion
# ./newEcom/gtec
# ./newEcom/biolane
# ./newEcom/genius
# ./newEcom/powerplant
# ./newEcom/zenit
# ./newEcom/phantom
# ./newEcom/sony
# ./newEcom/atlant
# ./newEcom/ecologystone
# ./newEcom/goodyear
# ./newEcom/anymode
# ./newEcom/mattel
# ./newEcom/gerat
# ./newEcom/okko
# ./newEcom/vivo
# ./newEcom/tefal
# ./newEcom/dougez
# ./newEcom/mio
# ./newEcom/epson
# ./newEcom/braun
# ./newEcom/grohe
# ./newEcom/sanc
# ./newEcom/superlux
# ./normalized
# ./L03
# ./shared
# ./shared/datafiles
# ./raw_data
# ./labeled
# ./students
# ./brandsData
# ./NOTES
# ./NOTES/Code
# ./Assignment2
# ./Assignment2/sales-data
# ./Assignment2/sales-data/.ipynb_checkpoints
# ./Assignment01
# ./Assignment01/.ipynb_checkpoints
# ./testdir
# ./testdir/sub1
# ./testdir/sub1/sub2
# ./L1L2
# ./.git
# ./.git/objects
# ./.git/objects/6f
# ./.git/objects/03
# ./.git/objects/6a
# ./.git/objects/5f
# ./.git/objects/05
# ./.git/objects/b5
# ./.git/objects/d9
# ./.git/objects/d7
# ./.git/objects/ab
# ./.git/objects/ec
# ./.git/objects/20
# ./.git/objects/4b
# ./.git/objects/pack
# ./.git/objects/11
# ./.git/objects/1f
# ./.git/objects/8a
# ./.git/objects/26
# ./.git/objects/81
# ./.git/objects/72
# ./.git/objects/43
# ./.git/objects/38
# ./.git/objects/info
# ./.git/objects/54
# ./.git/objects/37
# ./.git/objects/0a
# ./.git/objects/ff
# ./.git/objects/f1
# ./.git/objects/e0
# ./.git/objects/82
# ./.git/objects/2b
# ./.git/objects/8b
# ./.git/objects/7a
# ./.git/info
# ./.git/logs
# ./.git/logs/refs
# ./.git/logs/refs/heads
# ./.git/logs/refs/remotes
# ./.git/logs/refs/remotes/origin
# ./.git/hooks
# ./.git/refs
# ./.git/refs/heads
# ./.git/refs/tags
# ./.git/refs/remotes
# ./.git/refs/remotes/origin
# ./.git/gk
# ./ecom
# ./ecom/computers
# ./ecom/accessories
# ./ecom/stationery
# ./ecom/auto
# ./ecom/electronics
# ./ecom/appliances
# ./ecom/sport
# ./ecom/furniture
# ./ecom/medicine
# ./ecom/construction
# ./ecom/apparel
# ./ecom/kids
# ./ecom/country_yard
# ./data

# %%
grep "ERROR" sample.txt          # find all lines containing "ERROR"
grep -i "error" sample.txt        # case-insensitive search
grep -c "ERROR" sample.txt        # count matching lines
grep -n "ERROR" sample.txt        # show line numbers of matches
grep -v "INFO" sample.txt         # show lines NOT containing "INFO"
grep -r "TODO" ./data/            # recursive search in directory
grep -w "ERROR" sample.txt        # match whole word only
# Out:
# 0
# a
# b
# c
# d
# ./data/file1.txt:TODO: fixxxx
# : 1

# %% [markdown]
# ## 10. Permissions & Ownership

# %%
chmod 755 file1.txt    # Set permissions to rwxr-xr-x (owner full access, others read/execute)
chmod +x file1.txt     # Add execute permission to file1.txt
ls -l file1.txt        # Show file permissions and details

# %% [markdown]
# # 11. Redirection & Pipes

# %%
ls > files.txt            # Redirect ls output to files.txt (overwrite if it exists)
ls >> files.txt           # Append ls output to the end of files.txt
wc < files.txt            # Count lines, words, and bytes from files.txt via input redirection
cat files.txt | wc -l     # Count the number of lines in files.txt using a pipe

# %% [markdown]
# ## 12. wc (Word Count)

# %%
wc sample.txt        # Show number of lines, words, and bytes in sample.txt
wc -l sample.txt     # Show number of lines in sample.txt
wc -w sample.txt     # Show number of words in sample.txt
wc -c sample.txt     # Show number of bytes in sample.txt

# %% [markdown]
# ## 13. sort

# %%
echo -e "3\n1\n2" > nums.txt   # Create nums.txt with three lines: 3, 1, 2

# %%
sort nums.txt                  # Sort the lines alphabetically (lexicographically)
sort -r nums.txt               # Sort the lines in reverse order
sort -n nums.txt               # Sort the lines numerically
sort -b nums.txt               # Sort lines ignoring leading spaces

# %% [markdown]
# ## 15. cut

# %%
echo "a:b:c:d" > cut.txt         # Create cut.txt with the text "a:b:c:d"

# %%
cut -c1-3 cut.txt                # Extract characters 1 to 3 from each line
cut -d: -f1 cut.txt              # Extract the first field using ':' as the delimiter
cut -d: -f1,3 cut.txt            # Extract the first and third fields separated by ':'
cut -d: -f-3 cut.txt             # Extract fields 1 through 3 (inclusive) separated by ':'
cut -d: -f1-3 cut.txt            # Another way to extract fields 1 through 3 separated by ':'
cut -b1-4 cut.txt                # Extract bytes 1 to 4 from each line
# Out:
# a:b
# a
# a:c
# a:b:c
# a:b:c
# a:b:

# %% [markdown]
# ## 16. uniq

# %%
echo -e "a\na\nb\nb\nc" > uniq.txt   # Create uniq.txt with repeated letters

# %%
cat uniq.txt | sort | uniq
# Out:
# a
# b
# c

# %%
sort uniq.txt | uniq
# Out:
# a
# b
# c

# %%
sort uniq.txt | uniq                   # Remove duplicate lines (show unique lines)
sort uniq.txt | uniq -c                # Count occurrences of each line
sort uniq.txt | uniq -d                # Show only lines that are repeated
sort uniq.txt | uniq -u                # Show only lines that appear once
# Out:
# a
# b
# c
#    2 a
#    2 b
#    1 c
# a
# b
# c

# %% [markdown]
# ## 17. paste

# %%
echo -e "1\n2" > p1.txt           # Create p1.txt with lines 1 and 2
echo -e "A\nB" > p2.txt           # Create p2.txt with lines A and B

# %%
cat p2.txt
# Out:
# A
# B

# %%
cat p1.txt
paste -s p1.txt
# Out:
# 1
# 2
# 3
# 1	2	3

# %%
paste p1.txt p2.txt               # Merge files column-wise with default tab delimiter
paste -d, p1.txt p2.txt           # Merge files column-wise using ',' as the delimiter
paste -s p1.txt p2.txt            # Merge each file's lines into a single line (serial mode)
paste -sd, p1.txt                 # Merge all lines of p1.txt into a single line using ',' as delimiter
paste -sd,- p1.txt                 # Merge all lines of p1.txt into a single line using '-' as delimiter
ls | paste - - -                   # Combine output of ls into groups of 3 lines per row
# Out:
# 1	A
# 2	B
# 1,A
# 2,B
# 1	2
# A	B
# 1,2
# 1,2
# Exercise-1.ipynb	L02a.ipynb	L1L2
# clean_logs.txt	cut.txt	data
# file1.txt	files.txt	mock_logs.txt
# nums.txt	p1.txt	p2.txt
# practice.ipynb	sample.txt	testdir
# uniq.txt

# %%
paste -sd, p1.txt  p2.txt               # Merge all lines of p1.txt into a single line using ',' as delimiter
# Out:
# 1,2,3
# A,B

# %%
paste -d, p1.txt p2.txt           # Merge files column-wise using ',' as the delimiter
# Out:
# 1,A
# 2,B
# 3,

# %%
paste -s p1.txt p2.txt            # Merge each file's lines into a single line (serial mode)
# Out:
# 1	2	3
# A	B

# %%
paste -sd- p1.txt                 # Merge all lines of p1.txt into a single line using '-' as delimiter
# Out:
# 1-2-3

# %%
paste -sd,- p1.txt
# Out:
# 1,2-3

# %% [markdown]
# ## 18. tr

# %%
echo "hello" | tr 'e' 'a'            # Replace 'e' with 'a', output: hallo
echo "java" | tr '[ja]' '[eb]'       # Replace 'j'→'e' and 'a'→'b', output: ebbb
echo "hello" | tr 'a-z' 'A-Z'        # Convert all lowercase letters to uppercase, output: HELLO
echo "xxxxy" | tr -s 'x'             # Squeeze repeated 'x' characters into a single 'x', output: xy
echo "abcx" | tr -d 'x'              # Delete 'x' characters, output: abc
echo "a 1 b 2" | tr -d '[:space:]'   # Delete all whitespace characters, output: a1b2
echo "a1b2" | tr -d '[:digit:]'      # Delete all digits, output: ab
echo "a1b2" | tr -cd '[:digit:]'     # Keep only digits, deleting everything else, output: 12
# Out:
# hallo
# ebvb
# HELLO
# xy
# abc
# a1b2
# ab
# 12

# %%
echo "hello" | tr "e" "a"
echo "hello" | tr "[he]" "[el]"
# Out:
# hallo
# elllo

# %% [markdown]
# ## 19. sed

# %%
echo -e "apple\nbanana\napple\nbacon\ncat\ndog\napple pie\na b   c\n123\nb\nx y z" > sample.txt

# %%
sed 's/apple/orange/' sample.txt       # Replace first occurrence of 'apple' with 'orange' per line
sed 's/apple/orange/g' sample.txt      # Replace all occurrences of 'apple' with 'orange' per line
sed '2s/apple/orange/' sample.txt      # Replace 'apple' with 'orange' only on line 2
sed '/apple/s/apple/orange/' sample.txt # Replace 'apple' with 'orange' only on lines containing 'apple'
sed 's/^/hi/' sample.txt                # Add 'hi' to the beginning of each line
sed 's/$/hi/' sample.txt                # Add 'hi' to the end of each line
# Out:
# orange
# banana
# orange
# bacon
# cat
# dog
# orange pie
# a b   c
# 123
# b
# x y z
# orange
# banana
# orange
# bacon
# cat
# dog
# orange pie
# a b   c
# 123
# b
# x y z
# apple
# banana
# apple
# bacon
# cat
# dog
# apple pie
# a b   c
# 123
# b
# x y z
# orange
# banana
# orange
# bacon
# cat
# dog
# orange pie
# a b   c
# 123
# b
# x y z
# hiapple
# hibanana
# hiapple
# hibacon
# hicat
# hidog
# hiapple pie
# hia b   c
# hi123
# hib
# hix y z
# applehi
# bananahi
# applehi
# baconhi
# cathi
# doghi
# apple piehi
# a b   chi
# 123hi
# bhi
# x y zhi

# %%
sed '3d' sample.txt       # Delete line 3
sed '1,2d' sample.txt     # Delete lines 1 to 2
sed '$d' sample.txt       # Delete last line
sed '$d' sample.txt       # Delete last line
# Out:
# apple
# banana
# bacon
# cat
# dog
# apple pie
# a b   c
# 123
# b
# x y z
# apple
# bacon
# cat
# dog
# apple pie
# a b   c
# 123
# b
# x y z
# apple
# banana
# apple
# bacon
# cat
# dog
# apple pie
# a b   c
# 123
# b

# %% [markdown]
# ## 20. awk

# %%
echo "10 20" | awk '{print $0}'        # Print the entire line
echo "10 20" | awk '{print $1}'        # Print the first field
echo "10 20" | awk '{print $2}'        # Print the second field
echo "10 20" | awk '{print $1"\t"$2}'  # Print first and second fields separated by a tab
echo "10 20" | awk '{print $NF}'       # Print the last field of the line
# Out:
# 10 20
# 10
# 20
# 10	20
# 20

# %%
awk "{print $0}" sample.txt
# Out:
# awk: division by zero
#  input record number 1, file sample.txt
#  source line number 1
# : 2

# %%
cat sample.txt
# Out:
# a
# b
# c
# d
# SAMPLE
# ERROR
# ERROR101
# error
# ERROR first

# %%
echo "10,20" | cut -d ,  -f1-2
# Can only extract, cannot calculate
# Out:
# 10,20

# %%
echo "a:b:c" | awk -F ":" '{print $1}' # Print the first field using ':' as delimiter
echo "a:b:c" | awk -F ":" '{print $2}' # Print the second field using ':' as delimiter
# Out:
# a
# b

# %%
echo "10 20" | awk '{print $1 + $2}'   # Print the sum of the first and second fields
echo "10 20" | awk '{print $1 * $2}'   # Print the product of the first and second fields
# Out:
# 30
# 200
