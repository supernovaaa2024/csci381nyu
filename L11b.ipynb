# %% [markdown]
# # Mastering Data Visualization with Seaborn
# This notebook provides a comprehensive guide to the Seaborn library, covering everything from distribution plots to categorical analysis and advanced faceting.

# %% [markdown]
# ## 1. Setup and Sample Data
# First, we import the necessary libraries and create a synthetic dataset for our examples.

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Setting the theme
sns.set_theme(style="whitegrid")

# Generating a sample dataset
np.random.seed(42)
data = {
    'age': np.random.normal(35, 10, 200).astype(int),
    'salary': np.random.normal(50000, 15000, 200),
    'height': np.random.normal(170, 10, 200),
    'weight': np.random.normal(70, 15, 200),
    'gender': np.random.choice(['Male', 'Female'], 200),
    'department': np.random.choice(['Sales', 'IT', 'HR', 'Marketing'], 200),
    'experience': np.random.randint(1, 25, 200),
    'performance_score': np.random.uniform(1, 10, 200)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    age        salary      height     weight  gender department  experience  \
# 0   39  55366.810405  154.055723  81.354829  Female         HR           3
# 1   33  58411.767896  164.006250  56.167520    Male         IT           1
# 2   41  66245.768648  170.052437  83.044089  Female  Marketing           6
# 3   50  65807.030781  170.469806  90.334568    Male         HR          15
# 4   32  29334.959481  165.499345  76.201524    Male      Sales           2
#
#    performance_score
# 0           3.122129
# 1           7.984002
# 2           4.647792
# 3           6.416698
# 4           6.692865

# %% [markdown]
# ## 2. Distribution Plots
# Used to visualize the spread and density of numeric data.

# %%
# Histogram
sns.histplot(data=df, x="age", bins=20, kde=False);

# %%
# Kernel Density Estimate (KDE)
sns.kdeplot(data=df, x="age", fill=True);
sns.kdeplot(data=df, x='age', fill=True, hue='gender');
sns.kdeplot(data=df, x='age', fill=True, hue='department');

# %%
# Rug Plot
sns.rugplot(data=df, x="age");
# rug plot is often used in conjunction with KDE to show individual data points along the x-axis.

# %%
# ECDF Plot (Empirical Cumulative Distribution)
sns.ecdfplot(data=df, x="age");

# %% [markdown]
# ## 3. Relational Plots
# Used to identify relationships between multiple variables.

# %%
# Scatter Plot
sns.scatterplot(data=df, x='age', y='salary');
sns.scatterplot(data=df, x='age', y='salary', hue='gender');

# %%
# Regression Plot
sns.regplot(data=df, x="age", y="salary");
sns.lmplot(data=df, x='age', y='salary', hue='gender');

# %%
# Line Plot
sns.lineplot(data=df, x='age', y='salary');
sns.lineplot(data=df, x='age', y='salary', hue="gender");

# %%
# Pair Plot (Pairwise relationships)
sns.pairplot(df[['age', 'salary', 'experience', 'gender']], hue="gender");

# %%
# Joint Plot (Scatter + Distribution)
sns.jointplot(data=df, x="height", y="weight");
sns.jointplot(data=df, x="height", y="weight", kind="scatter", hue="gender");

# %% [markdown]
# ## 4. Categorical Plots
# Used to compare a numeric variable across different categories.

# %%
# Count Plot
sns.countplot(data=df, x="department");
sns.countplot(data=df, x="department", hue="gender");

# %%
# Box Plot
sns.boxplot(data=df, x="department", y="salary");

# %%
# Violin Plot
sns.violinplot(data=df, x="gender", y="performance_score");

# %%
# Strip plot
sns.stripplot(data=df, x='gender', y='salary');

# %%
# Swarm Plot
sns.swarmplot(data=df, x="department", y="experience");

# %%
# Bar plot
sns.barplot(data=df, x="gender", y="salary", hue="department");

# %% [markdown]
# ## 5. Matrix Plots
# Ideal for showing correlation and hierarchical clustering.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df[["salary", "age"]].corr()
sns.heatmap(df[["salary", "age", "experience"]].corr(), annot=True, cmap="coolwarm");

# %%
tdf=df.pivot_table(index='sex', columns='class', values='age', observed=False)
sns.heatmap(tdf, annot=True);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tdf=df.pivot_table(index='sex', columns='class', values='age', observed=False)
#       2 sns.heatmap(tdf, annot=True);
#
# File ~/.pyenv/versions/pythonfordata312/lib/python3.12/site-packages/pandas/core/frame.py:11143, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11125 @Substitution("")
#   11126 @Appender(_shared_docs["pivot_table"])
#   11127 def pivot_table(
#    (...)  11139     **kwargs,
#   11140 ) -> DataFrame:
#   11141     from pandas.core.reshape.pivot import pivot_table
# > 11143     return pivot_table(
#   11144         self,
#   11145         values=values,
#   11146         index=index,
#   11147         columns=columns,
#   11148         aggfunc=aggfunc,
#   11149         fill_value=fill_value,
# ...

# %%
# Heatmap (Correlation)
corr = df.select_dtypes(include=[np.number]).corr()
# sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f");

# %% [markdown]
# ## 6. Faceting (Small Multiples)
# Breaking down plots into a grid based on categorical variables.

# %%
# FacetGrid Example
sns.FacetGrid(df, col="gender", row="department").map(sns.histplot, "age")
sns.FacetGrid(df, col="gender", row="department", hue='department').map(sns.histplot, "age")
sns.FacetGrid(df, col="gender", row="department").map(scatterplot, "age","salary")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 sns.FacetGrid(df, col="gender", row="department").map(sns.histplot, "age")
#       3 sns.FacetGrid(df, col="gender", row="department", hue='department').map(sns.histplot, "age")
# ----> 4 sns.FacetGrid(df, col="gender", row="department").map(scatterplot, "age","salary")
#
# NameError: name 'scatterplot' is not defined

# %%
# Categorical Wrapper (catplot)
sns.catplot(data=df, x="department", y="salary", kind="boxen");
sns.catplot(data=df, x="department", y="salary", col="gender", kind="boxen")

# %% [markdown]
# ## 7. Theming and Customization
# Changing the look and scale of your visualizations.

# %%
# Change context and style
sns.set_context("talk")  # Scales labels for presentations
sns.set_style("darkgrid")
sns.set_palette("magma")

plt.figure(figsize=(8,5))
sns.barplot(data=df, x="gender", y="salary")
plt.title("Themed Bar Plot (Magma Palette)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Create sample data
data = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Sales', 'Sales'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Count': [45, 30, 20, 50, 40, 35]
}
df = pd.DataFrame(data)

# 2. Group by both categories and 'unstack' to prepare for plotting
# This moves 'Gender' from rows to columns so they can be stacked
plot_data = df.groupby(['Department', 'Gender'])['Count'].sum().unstack()

# 3. Create the Stacked Bar Chart
plot_data.plot(kind='bar', stacked=True, color=['#ff9999','#66b3ff'])

# Add labels and title
plt.title('Proportion of Gender by Department')
plt.ylabel('Employee Count')
plt.xlabel('Department')
plt.legend(title='Gender')
plt.show()
