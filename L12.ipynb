# %%
import requests
content= requests.get('https://www.usatoday.com/').text
type(content)
# Out:
# str

# %%
# pip install bs4

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(content)

# %%
soup.find_all('a')[4].text
# soup.find_all('img')[0]
# Out:
# 'Check home prices 🏠'

# %%
import requests
from bs4 import BeautifulSoup
content= requests.get('https://www.usatoday.com/').text
soup=BeautifulSoup(content)
news=[t.text for t in soup.find_all('a',{'class':'gnt_m_th_a'})]
f=open('news.txt', 'a')
f.write('\n'.join(news))
f.close()

# %%
news=[t.text for t in soup.find_all('a',{'class':'gnt_m_th_a'})]
links=[t['href'] for t in soup.find_all('a',{'class':'gnt_m_th_a'})]

print('\n'.join(news))
print('----------------------------------')
print('\n'.join(links))
# Out:
# FBI says package at Air Force base had 'possible energetic materials'
# 5 states still penalize you for not having health insurance
# WNBA, players union reach agreement in principle on new CBA
# Messi scores 900th goal: Here's how it happened with Inter Miami
# 'Real Housewives' stars visit Capitol Hill for HIV prevention awareness
# Eric Dane's wife, two daughters make first public sighting since his death
# Federal Reserve holds interest rates steady. What to know
# Trump DHS pick says he regrets disparaging Alex Pretti after shooting
# ----------------------------------
# /story/news/nation/2026/03/18/florida-air-force-base-energetic-materials-package-fbi/89218851007/
# /story/money/personalfinance/2026/03/18/states-penalty-no-health-insurance/89168539007/
# /story/sports/wnba/2026/03/18/wnba-players-union-agreement-in-principle-new-cba/87154047007/
# /story/sports/soccer/2026/03/18/lionel-messi-scores-900th-goal-in-inter-miami-match-vs-nashville-sc/89100543007/
# /picture-gallery/entertainment/celebrities/2026/03/18/real-housewives-hiv-dc-photo/89213428007/
# /story/entertainment/celebrities/2026/03/18/eric-dane-wife-rebecca-gayheart-daughters-public-appearance/89215612007/
# /live-story/money/2026/03/18/march-fed-meeting-live-updates-rate-decision/89169613007/
# /live-story/news/politics/2026/03/18/markwayne-mullin-dhs-confirmation-live-updates/89183629007/

# %%
! which python
# Out:
# /Users/owenhuang/.pyenv/versions/pythonfordata312/bin/python

# %%
# soup.find_all('a',{'class':'gnt_m_th_a'})[0].text
soup.find_all('a',{'class':'gnt_m_th_a'})[0]['href']
# Out:
# '/story/news/nation/2026/03/18/florida-air-force-base-energetic-materials-package-fbi/89218851007/'

# %%
keywords=' '.join(news).lower().replace('.','').replace(',','').split()
d={}
for w in keywords:
    if w not in d:
        d[w]=1
    else:
        d[w]+=1

# %%
from collections import Counter
# sorted(dict(Counter(keywords)).items(), key=lambda t:t[1])[::-1]
Counter(keywords)
# Out:
# Counter({'says': 2,
#          'for': 2,
#          'fbi': 1,
#          'package': 1,
#          'at': 1,
#          'air': 1,
#          'force': 1,
#          'base': 1,
#          'had': 1,
#          "'possible": 1,
#          'energetic': 1,
#          "materials'": 1,
#          '5': 1,
#          'states': 1,
#          'still': 1,
#          'penalize': 1,
#          'you': 1,
#          'not': 1,
#          'having': 1,
#          'health': 1,
#          'insurance': 1,
#          'wnba': 1,
#          'players': 1,
#          'union': 1,
#          'reach': 1,
#          'agreement': 1,
#          'in': 1,
#          'principle': 1,
#          'on': 1,
#          'new': 1,
#          'cba': 1,
#          'messi': 1,
#          'scores': 1,
#          '900th': 1,
#          'goal:': 1,
#          "here's": 1,
#          'how': 1,
#          'it': 1,
#          'happened': 1,
#          'with': 1,
#          'inter': 1,
#          'miami': 1,
#          "'real": 1,
#          "housewives'": 1,
#          'stars': 1,
#          'visit': 1,
#          'capitol': 1,
#          'hill': 1,
#          'hiv': 1,
#          'prevention': 1,
#          'awareness': 1,
#          'eric': 1,
#          "dane's": 1,
#          'wife': 1,
#          'two': 1,
#          'daughters': 1,
#          'make': 1,
#          'first': 1,
#          'public': 1,
#          'sighting': 1,
#          'since': 1,
#          'his': 1,
#          'death': 1,
#          'federal': 1,
#          'reserve': 1,
#          'holds': 1,
#          'interest': 1,
#          'rates': 1,
#          'steady': 1,
#          'what': 1,
#          'to': 1,
#          'know': 1,
#          'trump': 1,
#          'dhs': 1,
#          'pick': 1,
#          'he': 1,
#          'regrets': 1,
#          'disparaging': 1,
#          'alex': 1,
#          'pretti': 1,
#          'after': 1,
#          'shooting': 1})
