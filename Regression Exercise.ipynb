# %% [markdown]
# ## Exercise

# %% [markdown]
# Using the California housing dataset, predict `house prices` based on:
#
# - Average income
# - Number of rooms
# - Population
# - Latitude and longitude

# %%
# Your code here
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing()
X=data.data
Y=data.target

# %%
# Then use your model to predict the price for the following houses
import numpy as np
new_house=pd.DataFrame(np.array([[8 ,42., 5.98,1.05, 322. ,2.56,37.88,-122.23],
                                [7 ,44., 7.7,2.0, 211. ,1.4, 10.78, -100.3]]), columns=data.feature_names)
new_house
