# %% [markdown]
# ## **Exercise 1**
#
# ### **Scenario**
#
# - You consume data from multiple public APIs and want to ensure schema consistency before building a pipeline.
#
# ### **Data Source (Real API)**
#
# GitHub public repositories API (no key needed):
#
# - https://api.github.com/repos/pandas-dev/pandas
# - https://api.github.com/repos/numpy/numpy
# - https://api.github.com/repos/scikit-learn/scikit-learn
#
# ### **Tasks**
#
# - Fetch JSON from each API.
# - Verify whether there is any difference between the schemas (key sets)

# %%
# Fetch JSON from each API
import requests
with open("response1.json", "w") as f:
    f.write(requests.get("https://api.github.com/repos/pandas-dev/pandas").text)
with open("response2.json", "w") as f:
    f.write(requests.get("https://api.github.com/repos/numpy/numpy").text)
with open("response3.json", "w") as f:
    f.write(requests.get("https://api.github.com/repos/scikit-learn/scikit-learn").text)

# %%
# Your shell script code here
# Verify whether there is any difference between the schemas (key and value)

# Use Sets

# %% [markdown]
# ## **Exercise 2**
#
# ### **Scenario**
#
# You are auditing server access logs to detect abnormal traffic patterns.
#
# ### **Tasks**
# - Find unique IPs.
# - Identify the number of times error codes (404) appears.
# - Identify IPs producing only error codes (404).

# %%
import numpy as np
data = np.loadtxt('access.log', delimiter=' ', dtype=str)

# %%
len(set(data[:, 0]))
# Out:
# 22

# %%
# Nun of times 404 appears
data[data[:,1] == '404'].shape[0]
# Out:
# 205

# %%
# IPs producing only error codes 404 - Python
len(set(data[data[:,1] == '404'][:, 0]))
len(set(data[data[:,1] == '404'][:, 0]))
# Out:
# 20
